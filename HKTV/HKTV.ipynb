# %%
import requests
import urllib.parse
import sys
import json

# %%
categories = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_category_directory?lang=en&zone=housewares&maxLevel=3"
headers = {
    "accept-encoding":"gzip",
    "authorization":"Bearer f54b14d1-2cea-47e2-b044-6d246b2d61c0",
    "connection":"Keep-Alive",
    "cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=CB71E843B568BCE2091958BBA587F17A",
    "device-type":"android",
    "host":"www.hktvmall.com",
    "ott-uuid":"13542dde-009b-46ab-b3a9-fa1e256ce33b",
    "user-agent":"okhttp/2.2.0"
}

cat = requests.get(categories,headers = headers).json()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\python\python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\python\python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# c:\python\python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
cat['categories'][0]

# %%
'subcats' in cat['categories'][0]['subcats'][1]['subcats'][0].keys()

# %%
uu = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id=P0077002_S_FX3484560&lang=en&user_id=anonymous"
head = {
    "accept-encoding":"gzip",
"authorization":"Bearer 7f83db17-7cd1-4742-b814-14dd05daed7f",
"connection":"Keep-Alive",
"cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=0B05C4127AB75E4CFED31284A948BB10",
"device-type":"android",
"host":"www.hktvmall.com",
"ott-uuid":"e04d5772-cb0f-4356-acd5-96819447eb2d",
"user-agent":"okhttp/2.2.0"
}

# %%
produ = requests.get(uu,headers= head).json()

# %%
produ['baseOptions'][0]['options'][0]['variantOptionQualifiers']
# Out:
# [{'qualifier': 'Size', 'name': 'Size', 'value': 'UK 3.5', 'type': 'UK'}]

# %%
products_page_url_base = "https://www.hktvmall.com/hktvwebservices/v1/hktv/search_products_v2?query="

all_pages = []
for category in cat['categories'] :
    
    if 'subcats' in category.keys():        
        for subcat1 in category['subcats']:
            
            if 'subcats' in subcat1.keys():
                for subcat2 in subcat1['subcats']:
                    
                    if 'subcats' in subcat2.keys():                     
                        for subcat3 in subcat2['subcats']:
                            all_pages.append(subcat3)
                    
                    else:
                        all_pages.append(subcat2)                    
            else:
                all_pages.append(subcat1)
    else :
        all_pages.append(category)

# %%
all_pages_links = []

for pg in all_pages:
    all_pages_links.append(products_page_url_base+urllib.parse.quote(pg['query'])+"&lang=en&currentPage=0&pageSize=100000&user_id=anonymous")

# %%
tes = requests.get(all_pages_links[0],headers=headers).json()

# %%
tes['products'][0]
# Out:
# {'code': 'H1888001_S_16005842',
#  'name': 'froq Plastic Storage Box with Lid (M) - White',
#  'url': 'main/%E6%97%A5%E3%81%AE%E9%9B%9C%E8%B2%A8-Zakka-Home/s/H1888003/Housewares/Housewares/Storage-%26-Organisation/Plastic-Storage-Container/froq-Plastic-Storage-Box-with-Lid-M-White/p/H1888001_S_16005842',
#  'description': 'The cover can also be removed and washed, and the door can be removed with a single push. Easy to clean storage box <br> <br>For details, please refer to the label on the product. <br>The picture above is for reference only. The real object should be considered as final.',
#  'purchasable': True,
#  'stock': {'stockLevelStatus': {'code': 'inStock', 'codeLowerCase': 'instock'},
#   'stockLevel': 1,
#   'consignmentWarehouse': False,
#   'forceInStock': False},
#  'averageRating': 5.0,
#  'numberOfReviews': 5,
#  'summary': 'Made in Japan <br> <br>Size : 385x460x310Hmm <br> <br>Modular design, can be stacked for easy storage <br> <br>4 ways open lid',
# ...

# %%
https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?
    product_id=H0888001_S_10003577B
    &
    lang=en&no_stock_redirect=true&user_id=anonymous

# %%
all_products_links = []
for i,lnk in enumerate(all_pages_links) :
    multiple_prod_pg = requests.get(lnk,headers=headers).json()
    
    for prd in multiple_prod_pg['products']:
        all_products_links.append(prd)
        sys.stdout.write("\rDoing thing %i /495" % i)
        sys.stdout.flush()
# Out:
# Doing thing 2 /495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/897449181.py in <module>
#       1 all_products_links = []
#       2 for i,lnk in enumerate(all_pages_links) :
# ----> 3     multiple_prod_pg = requests.get(lnk,headers=headers).json()
#       4
#       5     for prd in multiple_prod_pg['products']:
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
for i,pr_lnk in enumerate(all_products_links):
    url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = head).json())
    sys.stdout.write("\rDoing thing %i /495000" % i)
    sys.stdout.flush()
# Out:
# Doing thing 10 /495000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/1284334702.py in <module>
#       3 for i,pr_lnk in enumerate(all_products_links):
#       4     url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ----> 5     products.append(requests.get(url,headers = head).json())
#       6     sys.stdout.write("\rDoing thing %i /495000" % i)
#       7     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
products[3]
# Out:
# {'code': 'H1888001_S_16003423',
#  'name': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#  'description': '',
#  'purchasable': True,
#  'stock': {'stockLevelStatus': {'code': 'inStock', 'codeLowerCase': 'instock'},
#   'stockLevel': 16,
#   'consignmentWarehouse': True,
#   'forceInStock': False},
#  'averageRating': 3.8,
#  'numberOfReviews': 119,
#  'summary': '550x390x330mm (48L)<br><br><br><br>3pcs/pack<br><br><br><br>Transparent Pink Lid w/Pink Handle <br><br><br><br>Product is make by imported PP (polypropylene) which is safe, ECO<br><br><br><br>Stackable <br><br><br><br>Easy locking lid',
#  'price': {'currencyIso': 'HKD',
#   'priceType': 'BUY',
#   'value': '299.0',
#   'membershipLevel': 'NORMAL',
#   'formattedValue': '$ 299.00'},
#  'baseProduct': 'H188800116003423',
#  'images': [{'imageType': 'PRIMARY',
#    'format': 'superZoom',
# ...

# %%
len(all_products_links)
# Out:
# 55226

# %% [markdown]
# # Master Loop

# %%
zones = ["thirteenlandmarks","supermarket","personalcarenhealth","beautynhealth","homenfamily","housewares","deals","sportsntravel"]
headers = {
    "accept-encoding":"gzip",
    "authorization":"Bearer 2de2ea56-4e3c-4401-9a76-c014c70bdc08",
    "connection":"Keep-Alive",
    "cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=7666D5240B540824DE19EFA71540EF49",
    "device-type":"android",
    "host":"www.hktvmall.com",
    "ott-uuid":"97665ca7-880e-43ce-8a11-5429d7a8a934",
    "user-agent":"okhttp/2.2.0"
}

all_pages = []
all_pages_links = []
products_page_url_base = "https://www.hktvmall.com/hktvwebservices/v1/hktv/search_products_v2?query="

for zone in zones:
    categories = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_category_directory?lang=en&zone="+zone+"&maxLevel=3"
    cat = requests.get(categories,headers = headers).json()
     
    for category in cat['categories'] :

        if 'subcats' in category.keys():        
            for subcat1 in category['subcats']:

                if 'subcats' in subcat1.keys():
                    for subcat2 in subcat1['subcats']:

                        if 'subcats' in subcat2.keys():                     
                            for subcat3 in subcat2['subcats']:
                                all_pages.append(subcat3)

                        else:
                            all_pages.append(subcat2)                    
                else:
                    all_pages.append(subcat1)
        else :
            all_pages.append(category)
    

for pg in all_pages:
    all_pages_links.append(products_page_url_base+urllib.parse.quote(pg['query'])+"&lang=en&currentPage=0&pageSize=100000&user_id=anonymous")

all_products_links = []
lengthpg = len(all_pages_links)
for i,lnk in enumerate(all_pages_links) :
    multiple_prod_pg = requests.get(lnk,headers=headers).json()
    
    for prd in multiple_prod_pg['products']:
        all_products_links.append(prd)
        sys.stdout.write(f"\rGenerating Product links %i /{lengthpg}" % i)
        sys.stdout.flush() 

        
product_codes = []
for cde in all_products_links:
    product_codes.append(cde['code'])

product_codes = list(set(product_codes))    

product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
lengthp = len(product_codes)
for i,pr_lnk in enumerate(product_codes):
    url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = head).json())
    sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
    sys.stdout.flush() 
    
with open('hktvdata.json', 'w') as outfile:
        json.dump(products, outfile)
        outfile.close()
# Out:
# Scraping product 466 /7485259 /2170
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/789568712.py in <module>
#      57 for i,pr_lnk in enumerate(all_products_links):
#      58     url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ---> 59     products.append(requests.get(url,headers = head).json())
#      60     sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
#      61     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
len(all_products_links)
# Out:
# 748525

# %%
product_codes[0]
# Out:
# 'H8450001_S_545_00002'

# %%
product_codes = []
for cde in all_products_links:
    product_codes.append(cde['code'])

product_codes = list(set(product_codes))

# %%
len(product_codes)
# Out:
# 466532

# %%
product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
lengthp = len(product_codes)
for i,pr_lnk in enumerate(product_codes):
    url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = headers).json())
    sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
    sys.stdout.flush() 
    
with open('hktvdata1.json', 'w') as outfile:
        json.dump(products, outfile)
        outfile.close()
# Out:
# Scraping product 2 /466532
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17240/2398862541.py in <module>
#       4 for i,pr_lnk in enumerate(product_codes):
#       5     url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ----> 6     products.append(requests.get(url,headers = headers).json())
#       7     sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
#       8     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# c:\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
# with open('codes.json', 'w') as outfile:
#         json.dump(product_codes, outfile)
#         outfile.close()

# %%
with open('codes.json') as json_file:
    product_codes = json.load(json_file)
    json_file.close()

# %%
products[0]['countryOfOrigin']
# Out:
# 'China'

# %%
import datetime


final_product = {
    'timestamp':'',
    'source':'',
    'country_code':'',
    'restaurant_id':'',
    'category':'',
    'items':'',
    'unmapped':'',
    'description':'',
    'sort_order':'',
    'items':'',
    'item_name':'',
    'item_id':'',
    'description':'',
    'available':'',
    'alcohol':'',
    'popular':'',
    'price':'',
    'price_unit':'',
    'discounted_price':'',
    'takeaway_price':'',
    'discounted_takeaway_price':'',
    'image_url':'',
    'labels':'',
    'promotion':'',
    'sort_order':'',
    'modifier_groups':{
        'modifier_groups_id':'',
        'name':'',
    },
    
    
}

# %%
import threading

# %%
def scrape(lock,urls):
    product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
    products = []
    lengthp = len(urls)
    for i,pr_lnk in enumerate(urls):
        lock.acquire()
        global globb
        globb += 1
        lock.release()
        url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
        products.append(requests.get(url,headers = head).json())
        sys.stdout.write(f"\rScraping product %i /{lengthp}" % globb)
        sys.stdout.flush() 
    lock.acquire()
    with open('hktvdata.json', 'a') as outfile:
            json.dump(products, outfile)
            outfile.close()
    lock.release()

# %%
lock = threading.Lock()
global globb 
globb = 0
# creating threads
threads = []
for i in range(100):
    if i == 99:
        t = threading.Thread(target=scrape, args=(lock,product_codes[i*4665:-1]))
    else:
        t = threading.Thread(target=scrape, args=(lock,product_codes[i*4665:(i+1)*4665]))
    threads.append(t)
#t1 = threading.Thread(target=scrape, args=(lock,product_codes[:100]))
#t2 = threading.Thread(target=scrape, args=(lock,product_codes[100:200]))

        # start threads
#t1.start()
#t2.start()

        # wait until threads finish their job
#t1.join()
#t2.join()
[ t.start() for t in threads ]
    # wait for the threads to finish
[ t.join() for t in threads ]
# Out:
# Scraping product 1177 /4665
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "c:\python\python39\lib\site-packages\urllib3\connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
# ...

# %%
with open('codes.json') as json_file:
    product_codes = json.load(json_file)
json_file.close()
    
product_codes = list(set(product_codes))
len(product_codes)
# Out:
# 466532

# %%
products[0].keys()
# Out:
# dict_keys(['code', 'name', 'description', 'purchasable', 'stock', 'averageRating', 'numberOfReviews', 'summary', 'price', 'baseProduct', 'images', 'categories', 'potentialPromotions', 'baseOptions', 'brandName', 'pickupdays', 'pickUpTimeslot', 'storeCode', 'storeCodeOriginal', 'storeName', 'storeType', 'storeRating', 'readyPickupDays', 'readyPickupHours', 'deliveryModeName', 'deliveryModeCode', 'storeDescription', 'deliveryRemarkFullMsg', 'packingSpec', 'countryOfOrigin', 'photosTabImages', 'numberOfColors', 'storeTC', 'deliveryOrReturnPolicy', 'storeLogo', 'recommendation', 'labels', 'returnDays', 'loyaltyPoint', 'storeLogos', 'priceList', 'promotionText', 'promotionStyle', 'productVideoUrls', 'thresholdPromotionList', 'bundlePromotionList', 'invisible', 'membershipLoyaltyPoint', 'deliveryPeriodMode', 'soldBy', 'subCatRecommendation', 'skuLevelRecommendation', 'categoryLevelRecommendation', 'savedPrice', 'productKeyword', 'subCatRecommendationName', 'skuLevelRecommendationName', 'ca
# ...

# %%
products[6]['recommendPercent']#[0]['code']
# Out:
# 0

# %%
## assume pr is one product // for pr in products:

category_list = []
for cat in pr['categories']:
    category_list.append( {'category_id':cat['code'],
            'name':cat['url'].split('/')[2],
            'description':'',
            'sort_order':,
            'items':,
            })

    
items_list = []
#modifier_groups = []


items_list.append({
        'item_name':pr['name'],
        'item_id':pr['code'],
        'description':pr['description'],
        'available':pr['purchasable'],
        'alcohol':'None',
        'popular':str(pr['recommendPercent']>=50 and True),
        'price':pr['price']['value'],
        'price_unit':pr['price']['currencyIso'],
        'discounted_price':pr['priceList'][1]['value'],
        'takeaway_price':'None',
        'discounted_takeaway_price':'None',
        'image_url':pr['photosTabImages'],
        'labels':pr['labels'],
        'promotion':pr['promotionText'],
        'sort_order':'None',
        'modifier_groups':{
                'modifier_groups_id':'None',
                'name':'None',
                'max_selection_points':'None',
                'min_selection_points':'None',
                'allow_multiple_same_item':'None',
                'description':'None',
                'available': False,
                'modifier_options':{
                                'name':'None',
                                'price':'None',
                                'option_id':'None',
                                'available':'None',
                                    }
                            }
    
})
    ###########
finalJson = {'timestamp':str(datetime.datetime.now()),
'source':'HKTV Mall App'
'country_code':'HK'
'restaurant_id':'1'
'unmapped':{}
'category': category_list        
    
'items': items_list     
        
    }

# %%
items_list = []
uniqueCatIds = set()
uniqueCats = []
category_list = []

for idx,pr in enumerate(products):    
    sys.stdout.write(f"\r Writing product %i /" %idx)
    sys.stdout.flush()
    modifier_options = []
    
    if len(pr['baseOptions'][0]['options'][0]['variantOptionQualifiers']) == 0:
        pass
    else:
        for mod in pr['baseOptions'][0]['options']:  
            modifier_options.append({'name':mod['variantOptionQualifiers'][0]['name'],
                                    'price':pr['price']['value'],
                                    'option_id':mod['code'],
                                    'available':mod['stock']['stockLevelStatus']['codeLowerCase'],})
    if len(pr['priceList']) > 1 :
        discountedPrice = pr['priceList'][1]['value']
        
    else:
        discountedPrice = 'None'
        
    if 'promotionText' in pr.keys():
        promotionText = pr['promotionText']
    else:
        promotionText = 'None'
    items_list.append({
        'item_name':pr['name'],
        'item_id':pr['code'],
        'description':pr['description'],
        'available':pr['purchasable'],
        'alcohol':'None',
        'popular':str(pr['recommendPercent']>=50 and True),
        'price':pr['price']['value'],
        'price_unit':pr['price']['currencyIso'],
        'discounted_price':discountedPrice ,
        'takeaway_price':'None',
        'discounted_takeaway_price':'None',
        'image_url':pr['photosTabImages'],
        'labels':pr['labels'],
        'promotion':promotionText,
        'sort_order':'None',
        'modifier_groups':[{
                'modifier_groups_id':'None',
                'name':'None',
                'max_selection_points':len(pr['baseOptions'][0]['options']),
                'min_selection_points':'1',
                'allow_multiple_same_item':str(pr['baseOptions'][0]['selected']['stock']['stockLevel'] > 1 and True) ,
                'description':'None',
                'available': str(pr['baseOptions'][0]['selected']['stock']['stockLevel'] > 0 and True),
                'modifier_options':modifier_options
                            }]
    
        })

    for cat in pr['categories']:
        if cat['code'] in uniqueCatIds:
            continue
        else:
            uniqueCatIds.add(cat['code'])
            uniqueCats.append(cat)
            
for cat in uniqueCats:
    item_ids = []
    for itm in products:
        for itmCat in itm['categories']:
            if itmCat['code'] == cat['code']:
                item_ids.append(itm['code'])
    
    category_list.append( {'category_id':cat['code'],
                    'name':cat['url'].split('/')[2],
                    'description':'None',
                    'sort_order':'None',
                    'items':item_ids,
                    })

finalJson = {'timestamp':str(datetime.datetime.now()),
'source':'HKTV Mall App',
'country_code':'HK',
'restaurant_id':'1',
'unmapped':products,
'category': category_list,        
'items': items_list     
        
    }
# Out:
#  Writing product 15 /

# %%
products[15]['priceList'][1]['value']
# Out:
# '8640.0'

# %%
len(pr['priceList'])>1 and
# Out:
# 13
