# %%
import requests
import urllib.parse
import sys
import json

# %%
categories = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_category_directory?lang=en&zone=housewares&maxLevel=3"
headers = {
    "accept-encoding":"gzip",
    "authorization":"Bearer 2de2ea56-4e3c-4401-9a76-c014c70bdc08",
    "connection":"Keep-Alive",
    "cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=7666D5240B540824DE19EFA71540EF49",
    "device-type":"android",
    "host":"www.hktvmall.com",
    "ott-uuid":"97665ca7-880e-43ce-8a11-5429d7a8a934",
    "user-agent":"okhttp/2.2.0"
}

cat = requests.get(categories,headers = headers).json()

# %%
cat['categories'][0]
# Out:
# {'count': 192659,
#  'name': 'Housewares',
#  'code': 'AA18000000000',
#  'query': ':relevance:street:main:category:AA18000000000',
#  'subcats': [{'count': 17267,
#    'name': 'Storage & Organisation',
#    'code': 'AA18050000000',
#    'query': ':relevance:street:main:category:AA18050000000',
#    'subcats': [{'count': 1500,
#      'name': 'Plastic Storage Container',
#      'code': 'AA18050500001',
#      'query': ':relevance:street:main:category:AA18050500001'},
#     {'count': 1122,
#      'name': 'Storage Drawers',
#      'code': 'AA18051000001',
#      'query': ':relevance:street:main:category:AA18051000001'},
#     {'count': 4241,
#      'name': 'Storage Cabinets',
#      'code': 'AA18051500001',
#      'query': ':relevance:street:main:category:AA18051500001'},
#     {'count': 1122,
#      'name': 'Storage Basket',
#      'code': 'AA18052000001',
#      'query': ':relevance:street:main:category:AA18052000001'},
#     {'count': 2739,
#      'name': 'Racks Shelves',
#      'code': 'AA18052500001',
#      'query': ':relevance:street:main:category:AA18052500001'},
#     {'count': 328,
#      'name': 'Fabric Storage Container & Stool',
#      'code': 'AA18053000001',
#      'query': ':relevance:street:main:category:AA18053000001'},
#     {'count': 82,
#      'name': 'Non-woven Wardrobe',
#      'code': 'AA18053500001',
#      'query': ':relevance:street:main:category:AA18053500001'},
#     {'count': 3083,
#      'name': 'Storage Bags',
#      'code': 'AA18054000000',
#      'query': ':relevance:street:main:category:AA18054000000',
#      'subcats': [{'count': 2651,
#        'name': 'General Storage Bags',
#        'code': 'AA18054010001',
#        'query': ':relevance:street:main:category:AA18054010001'},
#       {'count': 430,
#        'name': 'Vacuum Storage Bags',
#        'code': 'AA18054020001',
#        'query': ':relevance:street:main:category:AA18054020001'},
#       {'count': 265,
#        'name': 'Garment Bags',
#        'code': 'AA18054030001',
#        'query': ':relevance:street:main:category:AA18054030001'}]},
#     {'count': 1873,
#      'name': 'Hooks',
#      'code': 'AA18054500000',
#      'query': ':relevance:street:main:category:AA18054500000',
#      'subcats': [{'count': 1322,
#        'name': 'Adhesive Hooks',
#        'code': 'AA18054510001',
#        'query': ':relevance:street:main:category:AA18054510001'},
#       {'count': 339,
#        'name': 'Suction Hooks',
#        'code': 'AA18054520001',
#        'query': ':relevance:street:main:category:AA18054520001'},
#       {'count': 242,
#        'name': 'Wall Mounted Hooks',
#        'code': 'AA18054530001',
#        'query': ':relevance:street:main:category:AA18054530001'},
#       {'count': 252,
#        'name': 'S-Hooks',
#        'code': 'AA18054540001',
#        'query': ':relevance:street:main:category:AA18054540001'}]},
#     {'count': 705,
#      'name': 'Hangers',
#      'code': 'AA18054600001',
#      'query': ':relevance:street:main:category:AA18054600001'},
#     {'count': 379,
#      'name': 'Tissue Boxes & Covers',
#      'code': 'AA18054800001',
#      'query': ':relevance:street:main:category:AA18054800001'},
#     {'count': 428,
#      'name': 'Dividers',
#      'code': 'AA18055000001',
#      'query': ':relevance:street:main:category:AA18055000001'},
#     {'count': 800,
#      'name': 'Desk & Cable Organizer',
#      'code': 'AA18055500001',
#      'query': ':relevance:street:main:category:AA18055500001'},
#     {'count': 222,
#      'name': 'Storage Trolley',
#      'code': 'AA18056000001',
#      'query': ':relevance:street:main:category:AA18056000001'},
#     {'count': 1494,
#      'name': 'Shoes Storage',
#      'code': 'AA18056500001',
#      'query': ':relevance:street:main:category:AA18056500001'},
#     {'count': 2098,
#      'name': 'Storage Boxes',
#      'code': 'AA18057000001',
#      'query': ':relevance:street:main:category:AA18057000001'}]},
#   {'count': 17599,
#    'name': 'Cleaning',
#    'code': 'AA18100000000',
#    'query': ':relevance:street:main:category:AA18100000000',
#    'subcats': [{'count': 2382,
#      'name': 'Tissues',
#      'code': 'AA18100500000',
#      'query': ':relevance:street:main:category:AA18100500000',
#      'subcats': [{'count': 313,
#        'name': 'Bathroom Tissues',
#        'code': 'AA18100510001',
#        'query': ':relevance:street:main:category:AA18100510001'},
#       {'count': 329,
#        'name': 'Boxed Facial Tissues',
#        'code': 'AA18100520001',
#        'query': ':relevance:street:main:category:AA18100520001'},
#       {'count': 414,
#        'name': 'Kitchen Towels',
#        'code': 'AA18100530001',
#        'query': ':relevance:street:main:category:AA18100530001'},
#       {'count': 124,
#        'name': 'Mini Tissues',
#        'code': 'AA18100540001',
#        'query': ':relevance:street:main:category:AA18100540001'},
#       {'count': 1245,
#        'name': 'Wet Wipes',
#        'code': 'AA18100550001',
#        'query': ':relevance:street:main:category:AA18100550001'}]},
#     {'count': 5495,
#      'name': 'Household Cleaners',
#      'code': 'AA18101000000',
#      'query': ':relevance:street:main:category:AA18101000000',
#      'subcats': [{'count': 1017,
#        'name': 'Dish Washing & Food Detergents',
#        'code': 'AA18101005001',
#        'query': ':relevance:street:main:category:AA18101005001'},
#       {'count': 898,
#        'name': 'Kitchen Cleaners',
#        'code': 'AA18101010001',
#        'query': ':relevance:street:main:category:AA18101010001'},
#       {'count': 411,
#        'name': 'Furniture Cleaners & Care',
#        'code': 'AA18101015001',
#        'query': ':relevance:street:main:category:AA18101015001'},
#       {'count': 101,
#        'name': 'Metal Cleaners',
#        'code': 'AA18101020001',
#        'query': ':relevance:street:main:category:AA18101020001'},
#       {'count': 222,
#        'name': 'Glass Cleaners',
#        'code': 'AA18101025001',
#        'query': ':relevance:street:main:category:AA18101025001'},
#       {'count': 312,
#        'name': 'Floor Cleaners',
#        'code': 'AA18101030001',
#        'query': ':relevance:street:main:category:AA18101030001'},
#       {'count': 680,
#        'name': 'Toilet Bowl Cleaners',
#        'code': 'AA18101035001',
#        'query': ':relevance:street:main:category:AA18101035001'},
#       {'count': 256,
#        'name': 'Bathtub & Tile Cleaners',
#        'code': 'AA18101040001',
#        'query': ':relevance:street:main:category:AA18101040001'},
#       {'count': 302,
#        'name': 'Drain Cleaners',
#        'code': 'AA18101045001',
#        'query': ':relevance:street:main:category:AA18101045001'},
#       {'count': 109,
#        'name': 'Pet Ordin Removers',
#        'code': 'AA18101050001',
#        'query': ':relevance:street:main:category:AA18101050001'},
#       {'count': 294,
#        'name': 'Bleach',
#        'code': 'AA18101055001',
#        'query': ':relevance:street:main:category:AA18101055001'},
#       {'count': 372,
#        'name': 'Washing Machine Cleaners',
#        'code': 'AA18101060001',
#        'query': ':relevance:street:main:category:AA18101060001'},
#       {'count': 95,
#        'name': 'Air-Conditioner Cleaners',
#        'code': 'AA18101065001',
#        'query': ':relevance:street:main:category:AA18101065001'},
#       {'count': 34,
#        'name': 'Carpet Cleaners',
#        'code': 'AA18101070001',
#        'query': ':relevance:street:main:category:AA18101070001'},
#       {'count': 216,
#        'name': 'Car Cleaners',
#        'code': 'AA18101075001',
#        'query': ':relevance:street:main:category:AA18101075001'},
#       {'count': 1291,
#        'name': 'Multi-functional Cleaners',
#        'code': 'AA18101080001',
#        'query': ':relevance:street:main:category:AA18101080001'}]},
#     {'count': 4224,
#      'name': 'Cleaning Tools',
#      'code': 'AA18101500000',
#      'query': ':relevance:street:main:category:AA18101500000',
#      'subcats': [{'count': 886,
#        'name': 'Cleaning Cloths',
#        'code': 'AA18101505001',
#        'query': ':relevance:street:main:category:AA18101505001'},
#       {'count': 74,
#        'name': 'Steel Cleaning Balls',
#        'code': 'AA18101510001',
#        'query': ':relevance:street:main:category:AA18101510001'},
#       {'count': 762,
#        'name': 'Scouring Pads & Sponges',
#        'code': 'AA18101515001',
#        'query': ':relevance:street:main:category:AA18101515001'},
#       {'count': 407,
#        'name': 'Mops & Brooms',
#        'code': 'AA18101520001',
#        'query': ':relevance:street:main:category:AA18101520001'},
#       {'count': 251,
#        'name': 'Plastic Buckets',
#        'code': 'AA18101525001',
#        'query': ':relevance:street:main:category:AA18101525001'},
#       {'count': 245,
#        'name': 'Toilet Brushes',
#        'code': 'AA18101530001',
#        'query': ':relevance:street:main:category:AA18101530001'},
#       {'count': 42,
#        'name': 'Toilet Plungers',
#        'code': 'AA18101535001',
#        'query': ':relevance:street:main:category:AA18101535001'},
#       {'count': 220,
#        'name': 'Lint Rollers & Refill',
#        'code': 'AA18101540001',
#        'query': ':relevance:street:main:category:AA18101540001'},
#       {'count': 892,
#        'name': 'Cleaning Brushes',
#        'code': 'AA18101545001',
#        'query': ':relevance:street:main:category:AA18101545001'},
#       {'count': 784,
#        'name': 'Cleaning Gloves',
#        'code': 'AA18101550001',
#        'query': ':relevance:street:main:category:AA18101550001'},
#       {'count': 215,
#        'name': 'Dusting Tools',
#        'code': 'AA18101555001',
#        'query': ':relevance:street:main:category:AA18101555001'}]},
#     {'count': 285,
#      'name': 'Garbage Bag',
#      'code': 'AA18102000001',
#      'query': ':relevance:street:main:category:AA18102000001'},
#     {'count': 512,
#      'name': 'Garbage Bins',
#      'code': 'AA18102500000',
#      'query': ':relevance:street:main:category:AA18102500000',
#      'subcats': [{'count': 445,
#        'name': 'Kitchen Bins',
#        'code': 'AA18102510001',
#        'query': ':relevance:street:main:category:AA18102510001'},
#       {'count': 224,
#        'name': 'Bathroom Bins',
#        'code': 'AA18102520001',
#        'query': ':relevance:street:main:category:AA18102520001'},
#       {'count': 146,
#        'name': 'Open Topped Bins',
#        'code': 'AA18102530001',
#        'query': ':relevance:street:main:category:AA18102530001'}]},
#     {'count': 983,
#      'name': 'Dehumidifying Products',
#      'code': 'AA18103000000',
#      'query': ':relevance:street:main:category:AA18103000000',
#      'subcats': [{'count': 348,
#        'name': 'Dehumidifying Crystals & Liquids',
#        'code': 'AA18103010001',
#        'query': ':relevance:street:main:category:AA18103010001'},
#       {'count': 681,
#        'name': 'Dehumidifiers',
#        'code': 'AA18103020001',
#        'query': ':relevance:street:main:category:AA18103020001'},
#       {'count': 130,
#        'name': 'Diatomite',
#        'code': 'AA18103030001',
#        'query': ':relevance:street:main:category:AA18103030001'}]},
#     {'count': 891,
#      'name': 'Pest Control',
#      'code': 'AA18103500000',
#      'query': ':relevance:street:main:category:AA18103500000',
#      'subcats': [{'count': 234,
#        'name': 'Pesticide Sprays',
#        'code': 'AA18103510001',
#        'query': ':relevance:street:main:category:AA18103510001'},
#       {'count': 222,
#        'name': 'Miticide Sprays & Stickers',
#        'code': 'AA18103520001',
#        'query': ':relevance:street:main:category:AA18103520001'},
#       {'count': 194,
#        'name': 'Cockroach Traps',
#        'code': 'AA18103530001',
#        'query': ':relevance:street:main:category:AA18103530001'},
#       {'count': 47,
#        'name': 'Mice Traps',
#        'code': 'AA18103540001',
#        'query': ':relevance:street:main:category:AA18103540001'},
#       {'count': 206,
#        'name': 'Mosquito Coils & Rackets',
#        'code': 'AA18103550001',
#        'query': ':relevance:street:main:category:AA18103550001'},
#       {'count': 83,
#        'name': 'Mosquito Bracelets & Stickers',
#        'code': 'AA18103560001',
#        'query': ':relevance:street:main:category:AA18103560001'}]},
#     {'count': 3106,
#      'name': 'Air Refresher',
#      'code': 'AA18104000000',
#      'query': ':relevance:street:main:category:AA18104000000',
#      'subcats': [{'count': 1057,
#        'name': 'Air Refresher Spray',
#        'code': 'AA18104010001',
#        'query': ':relevance:street:main:category:AA18104010001'},
#       {'count': 690,
#        'name': 'Bathroom Air Refresher',
#        'code': 'AA18104020001',
#        'query': ':relevance:street:main:category:AA18104020001'},
#       {'count': 297,
#        'name': 'Car Air Refresher',
#        'code': 'AA18104030001',
#        'query': ':relevance:street:main:category:AA18104030001'},
#       {'count': 182,
#        'name': 'Refrigerator Deodorizer',
#        'code': 'AA18104040001',
#        'query': ':relevance:street:main:category:AA18104040001'},
#       {'count': 1269,
#        'name': 'Disinfectant Spray',
#        'code': 'AA18104050001',
#        'query': ':relevance:street:main:category:AA18104050001'}]},
#     {'count': 569,
#      'name': 'Closet & Shoe Cabinet Products',
#      'code': 'AA18104500000',
#      'query': ':relevance:street:main:category:AA18104500000',
#      'subcats': [{'count': 24,
#        'name': 'Mothballs',
#        'code': 'AA18104510001',
#        'query': ':relevance:street:main:category:AA18104510001'},
#       {'count': 325,
#        'name': 'Closet Deodorizer',
#        'code': 'AA18104520001',
#        'query': ':relevance:street:main:category:AA18104520001'},
#       {'count': 171,
#        'name': 'Pest Control Tablets',
#        'code': 'AA18104530001',
#        'query': ':relevance:street:main:category:AA18104530001'},
#       {'count': 41,
#        'name': 'Cabinet Mats',
#        'code': 'AA18104540001',
#        'query': ':relevance:street:main:category:AA18104540001'},
#       {'count': 61,
#        'name': 'Linen Hair Removers',
#        'code': 'AA18104550001',
#        'query': ':relevance:street:main:category:AA18104550001'}]}]},
#   {'count': 16839,
#    'name': 'Kitchenware',
#    'code': 'AA18150000000',
#    'query': ':relevance:street:main:category:AA18150000000',
#    'subcats': [{'count': 1524,
#      'name': 'Woks & Pans',
#      'code': 'AA18150500000',
#      'query': ':relevance:street:main:category:AA18150500000',
#      'subcats': [{'count': 914,
#        'name': 'Fry Pans',
#        'code': 'AA18150510001',
#        'query': ':relevance:street:main:category:AA18150510001'},
#       {'count': 375,
#        'name': 'Woks',
#        'code': 'AA18150520001',
#        'query': ':relevance:street:main:category:AA18150520001'},
#       {'count': 287,
#        'name': 'Grill Pans',
#        'code': 'AA18150530001',
#        'query': ':relevance:street:main:category:AA18150530001'},
#       {'count': 190,
#        'name': 'Cookware Sets',
#        'code': 'AA18150540001',
#        'query': ':relevance:street:main:category:AA18150540001'},
#       {'count': 500,
#        'name': 'Induction Compatible Pans',
#        'code': 'AA18150550001',
#        'query': ':relevance:street:main:category:AA18150550001'}]},
#     {'count': 1532,
#      'name': 'Pots',
#      'code': 'AA18151000000',
#      'query': ':relevance:street:main:category:AA18151000000',
#      'subcats': [{'count': 382,
#        'name': 'Single Handle Pots',
#        'code': 'AA18151005001',
#        'query': ':relevance:street:main:category:AA18151005001'},
#       {'count': 507,
#        'name': 'Double Handle Pots',
#        'code': 'AA18151010001',
#        'query': ':relevance:street:main:category:AA18151010001'},
#       {'count': 146,
#        'name': 'Hot-Pot Pots',
#        'code': 'AA18151015001',
#        'query': ':relevance:street:main:category:AA18151015001'},
#       {'count': 61,
#        'name': 'Pressure Cooker',
#        'code': 'AA18151020001',
#        'query': ':relevance:street:main:category:AA18151020001'},
#       {'count': 67,
#        'name': 'Earthen Pot & Clay Pot',
#        'code': 'AA18151025001',
#        'query': ':relevance:street:main:category:AA18151025001'},
#       {'count': 133,
#        'name': 'Tea Kettle',
#        'code': 'AA18151030001',
#        'query': ':relevance:street:main:category:AA18151030001'},
#       {'count': 99,
#        'name': 'Steamer Basket',
#        'code': 'AA18151035001',
#        'query': ':relevance:street:main:category:AA18151035001'},
#       {'count': 129,
#        'name': 'Pots Sets',
#        'code': 'AA18151040001',
#        'query': ':relevance:street:main:category:AA18151040001'},
#       {'count': 473,
#        'name': 'Induction Compatible Pots',
#        'code': 'AA18151045001',
#        'query': ':relevance:street:main:category:AA18151045001'},
#       {'count': 137,
#        'name': 'Pot Lid Knob',
#        'code': 'AA18151050001',
#        'query': ':relevance:street:main:category:AA18151050001'}]},
#     {'count': 1807,
#      'name': 'Knives',
#      'code': 'AA18151500000',
#      'query': ':relevance:street:main:category:AA18151500000',
#      'subcats': [{'count': 531,
#        'name': 'Chef Knives',
#        'code': 'AA18151510001',
#        'query': ':relevance:street:main:category:AA18151510001'},
#       {'count': 298,
#        'name': 'Vegetable Knives',
#        'code': 'AA18151520001',
#        'query': ':relevance:street:main:category:AA18151520001'},
#       {'count': 336,
#        'name': 'Fruit Knives',
#        'code': 'AA18151530001',
#        'query': ':relevance:street:main:category:AA18151530001'},
#       {'count': 92,
#        'name': 'Bread Knives',
#        'code': 'AA18151540001',
#        'query': ':relevance:street:main:category:AA18151540001'},
#       {'count': 51,
#        'name': 'Ceramic Knives',
#        'code': 'AA18151550001',
#        'query': ':relevance:street:main:category:AA18151550001'},
#       {'count': 715,
#        'name': 'Peelers',
#        'code': 'AA18151560001',
#        'query': ':relevance:street:main:category:AA18151560001'},
#       {'count': 87,
#        'name': 'Cheese Knives',
#        'code': 'AA18151570001',
#        'query': ':relevance:street:main:category:AA18151570001'},
#       {'count': 306,
#        'name': 'Knives Sets',
#        'code': 'AA18151580001',
#        'query': ':relevance:street:main:category:AA18151580001'},
#       {'count': 66,
#        'name': 'Cake & Pizza Cutters',
#        'code': 'AA18151590001',
#        'query': ':relevance:street:main:category:AA18151590001'}]},
#     {'count': 862,
#      'name': 'Chopping Boards & Knife Storage',
#      'code': 'AA18152000000',
#      'query': ':relevance:street:main:category:AA18152000000',
#      'subcats': [{'count': 281,
#        'name': 'Wooden Chopping Boards',
#        'code': 'AA18152010001',
#        'query': ':relevance:street:main:category:AA18152010001'},
#       {'count': 334,
#        'name': 'Plastic Chopping Boards',
#        'code': 'AA18152020001',
#        'query': ':relevance:street:main:category:AA18152020001'},
#       {'count': 200,
#        'name': 'Knife Storage',
#        'code': 'AA18152030001',
#        'query': ':relevance:street:main:category:AA18152030001'},
#       {'count': 160,
#        'name': 'Knife Sharpeners',
#        'code': 'AA18152040001',
#        'query': ':relevance:street:main:category:AA18152040001'}]},
#     {'count': 464,
#      'name': 'Kitchen Scissors',
#      'code': 'AA18152500001',
#      'query': ':relevance:street:main:category:AA18152500001'},
#     {'count': 6967,
#      'name': 'Cooking & Baking Tools',
#      'code': 'AA18153000000',
#      'query': ':relevance:street:main:category:AA18153000000',
#      'subcats': [{'count': 483,
#        'name': 'Spatula',
#        'code': 'AA18153003001',
#        'query': ':relevance:street:main:category:AA18153003001'},
#       {'count': 338,
#        'name': 'Soup Scoop',
#        'code': 'AA18153006001',
#        'query': ':relevance:street:main:category:AA18153006001'},
#       {'count': 162,
#        'name': 'Rice Scoop',
#        'code': 'AA18153010001',
#        'query': ':relevance:street:main:category:AA18153010001'},
#       {'count': 97,
#        'name': 'Steamer Rack',
#        'code': 'AA18153013001',
#        'query': ':relevance:street:main:category:AA18153013001'},
#       {'count': 368,
#        'name': 'Cooking Tweezers',
#        'code': 'AA18153016001',
#        'query': ':relevance:street:main:category:AA18153016001'},
#       {'count': 169,
#        'name': 'Spaghetti Tongs',
#        'code': 'AA18153020001',
#        'query': ':relevance:street:main:category:AA18153020001'},
#       {'count': 36,
#        'name': 'Meat Tenderizers',
#        'code': 'AA18153023001',
#        'query': ':relevance:street:main:category:AA18153023001'},
#       {'count': 150,
#        'name': 'Pastry Brushes',
#        'code': 'AA18153026001',
#        'query': ':relevance:street:main:category:AA18153026001'},
#       {'count': 46,
#        'name': 'Rolling Pins',
#        'code': 'AA18153030001',
#        'query': ':relevance:street:main:category:AA18153030001'},
#       {'count': 71,
#        'name': 'Flour Sifters',
#        'code': 'AA18153033001',
#        'query': ':relevance:street:main:category:AA18153033001'},
#       {'count': 109,
#        'name': 'Egg Cutters',
#        'code': 'AA18153036001',
#        'query': ':relevance:street:main:category:AA18153036001'},
#       {'count': 154,
#        'name': 'Whisks',
#        'code': 'AA18153040001',
#        'query': ':relevance:street:main:category:AA18153040001'},
#       {'count': 183,
#        'name': 'Can Openers',
#        'code': 'AA18153043001',
#        'query': ':relevance:street:main:category:AA18153043001'},
#       {'count': 414,
#        'name': 'Strainers',
#        'code': 'AA18153046001',
#        'query': ':relevance:street:main:category:AA18153046001'},
#       {'count': 393,
#        'name': 'Pot Holders',
#        'code': 'AA18153050001',
#        'query': ':relevance:street:main:category:AA18153050001'},
#       {'count': 1634,
#        'name': 'Baking Pans & Molds',
#        'code': 'AA18153053001',
#        'query': ':relevance:street:main:category:AA18153053001'},
#       {'count': 216,
#        'name': 'Rubber Spatula',
#        'code': 'AA18153056001',
#        'query': ':relevance:street:main:category:AA18153056001'},
#       {'count': 490,
#        'name': 'Baking Mats',
#        'code': 'AA18153060001',
#        'query': ':relevance:street:main:category:AA18153060001'},
#       {'count': 174,
#        'name': 'Timers',
#        'code': 'AA18153063001',
#        'query': ':relevance:street:main:category:AA18153063001'},
#       {'count': 169,
#        'name': 'Measure Cups',
#        'code': 'AA18153066001',
#        'query': ':relevance:street:main:category:AA18153066001'},
#       {'count': 254,
#        'name': 'Measure Spoons',
#        'code': 'AA18153070001',
#        'query': ':relevance:street:main:category:AA18153070001'},
#       {'count': 135,
#        'name': 'Electronic Scales',
#        'code': 'AA18153073001',
#        'query': ':relevance:street:main:category:AA18153073001'},
#       {'count': 142,
#        'name': 'Mixing Bowls',
#        'code': 'AA18153076001',
#        'query': ':relevance:street:main:category:AA18153076001'},
#       {'count': 409,
#        'name': 'Ice Makers',
#        'code': 'AA18153080001',
#        'query': ':relevance:street:main:category:AA18153080001'},
#       {'count': 127,
#        'name': 'Juicers',
#        'code': 'AA18153083001',
#        'query': ':relevance:street:main:category:AA18153083001'},
#       {'count': 121,
#        'name': 'Food Thermometers',
#        'code': 'AA18153086001',
#        'query': ':relevance:street:main:category:AA18153086001'},
#       {'count': 319,
#        'name': 'Cooking Torches',
#        'code': 'AA18153090001',
#        'query': ':relevance:street:main:category:AA18153090001'},
#       {'count': 297,
#        'name': 'Dish Racks & Drainers',
#        'code': 'AA18153092001',
#        'query': ':relevance:street:main:category:AA18153092001'},
#       {'count': 158,
#        'name': 'Salad Spoons & Forks',
#        'code': 'AA18153094001',
#        'query': ':relevance:street:main:category:AA18153094001'},
#       {'count': 101,
#        'name': 'Cheese Graters',
#        'code': 'AA18153096001',
#        'query': ':relevance:street:main:category:AA18153096001'},
#       {'count': 201,
#        'name': 'Garlic Press & Potato Mashers',
#        'code': 'AA18153098001',
#        'query': ':relevance:street:main:category:AA18153098001'}]},
#     {'count': 959,
#      'name': 'Kitchen Hooks',
#      'code': 'AA18153200001',
#      'query': ':relevance:street:main:category:AA18153200001'},
#     {'count': 160,
#      'name': 'Rice Storage Boxes',
#      'code': 'AA18153400001',
#      'query': ':relevance:street:main:category:AA18153400001'},
#     {'count': 939,
#      'name': 'Seasoning Containers',
#      'code': 'AA18153500001',
#      'query': ':relevance:street:main:category:AA18153500001'},
#     {'count': 323,
#      'name': 'Oven Gloves',
#      'code': 'AA18154000001',
#      'query': ':relevance:street:main:category:AA18154000001'},
#     {'count': 534,
#      'name': 'Apron',
#      'code': 'AA18154500001',
#      'query': ':relevance:street:main:category:AA18154500001'},
#     {'count': 835,
#      'name': 'Kitchen Consumables',
#      'code': 'AA18155000000',
#      'query': ':relevance:street:main:category:AA18155000000',
#      'subcats': [{'count': 388,
#        'name': 'Food Wrap',
#        'code': 'AA18155010001',
#        'query': ':relevance:street:main:category:AA18155010001'},
#       {'count': 211,
#        'name': 'Foil & Parchment Paper',
#        'code': 'AA18155020001',
#        'query': ':relevance:street:main:category:AA18155020001'},
#       {'count': 40,
#        'name': 'Foil Range Covers',
#        'code': 'AA18155030001',
#        'query': ':relevance:street:main:category:AA18155030001'},
#       {'count': 24,
#        'name': 'Foil Containers',
#        'code': 'AA18155040001',
#        'query': ':relevance:street:main:category:AA18155040001'},
#       {'count': 79,
#        'name': 'Kitchen Wall Stickers',
#        'code': 'AA18155050001',
#        'query': ':relevance:street:main:category:AA18155050001'},
#       {'count': 167,
#        'name': 'Cotten Paper Oil Filters',
#        'code': 'AA18155060001',
#        'query': ':relevance:street:main:category:AA18155060001'}]},
#     {'count': 475,
#      'name': 'Sink Strainer Baskets',
#      'code': 'AA18155500001',
#      'query': ':relevance:street:main:category:AA18155500001'},
#     {'count': 923,
#      'name': 'Water Filter',
#      'code': 'AA18156000001',
#      'query': ':relevance:street:main:category:AA18156000001'},
#     {'count': 168,
#      'name': 'Kitchen Construction Materials',
#      'code': 'AA18157000000',
#      'query': ':relevance:street:main:category:AA18157000000',
#      'subcats': [{'count': 93,
#        'name': 'Kitchen Sinks',
#        'code': 'AA18157010001',
#        'query': ':relevance:street:main:category:AA18157010001'},
#       {'count': 84,
#        'name': 'Kitchen Faucets',
#        'code': 'AA18157020001',
#        'query': ':relevance:street:main:category:AA18157020001'}]}]},
#   {'count': 19289,
#    'name': 'Tableware',
#    'code': 'AA18200000000',
#    'query': ':relevance:street:main:category:AA18200000000',
#    'subcats': [{'count': 2098,
#      'name': 'Chinese Tableware',
#      'code': 'AA18200500000',
#      'query': ':relevance:street:main:category:AA18200500000',
#      'subcats': [{'count': 887,
#        'name': 'Chopsticks & Chopsticks Holders',
#        'code': 'AA18200510001',
#        'query': ':relevance:street:main:category:AA18200510001'},
#       {'count': 270,
#        'name': 'Soup Spoons',
#        'code': 'AA18200520001',
#        'query': ':relevance:street:main:category:AA18200520001'},
#       {'count': 667,
#        'name': 'Rice Bowls',
#        'code': 'AA18200530001',
#        'query': ':relevance:street:main:category:AA18200530001'},
#       {'count': 541,
#        'name': 'Soup Bowls',
#        'code': 'AA18200540001',
#        'query': ':relevance:street:main:category:AA18200540001'},
#       {'count': 163,
#        'name': 'Long Handle Spoons',
#        'code': 'AA18200550001',
#        'query': ':relevance:street:main:category:AA18200550001'},
#       {'count': 36,
#        'name': 'Hot Pot Strainers',
#        'code': 'AA18200560001',
#        'query': ':relevance:street:main:category:AA18200560001'},
#       {'count': 52,
#        'name': 'Crab Tools',
#        'code': 'AA18200570001',
#        'query': ':relevance:street:main:category:AA18200570001'}]},
#     {'count': 1270,
#      'name': 'Western Tableware',
#      'code': 'AA18201000000',
#      'query': ':relevance:street:main:category:AA18201000000',
#      'subcats': [{'count': 149,
#        'name': 'Table Knives',
#        'code': 'AA18201010001',
#        'query': ':relevance:street:main:category:AA18201010001'},
#       {'count': 353,
#        'name': 'Forks',
#        'code': 'AA18201020001',
#        'query': ':relevance:street:main:category:AA18201020001'},
#       {'count': 595,
#        'name': 'Table Spoons',
#        'code': 'AA18201030001',
#        'query': ':relevance:street:main:category:AA18201030001'},
#       {'count': 257,
#        'name': 'Salad Bowls',
#        'code': 'AA18201040001',
#        'query': ':relevance:street:main:category:AA18201040001'},
#       {'count': 75,
#        'name': 'Pastry Racks',
#        'code': 'AA18201050001',
#        'query': ':relevance:street:main:category:AA18201050001'}]},
#     {'count': 816,
#      'name': 'Tableware Containers',
#      'code': 'AA18201500001',
#      'query': ':relevance:street:main:category:AA18201500001'},
#     {'count': 1505,
#      'name': 'Plates and Trays',
#      'code': 'AA18202000000',
#      'query': ':relevance:street:main:category:AA18202000000',
#      'subcats': [{'count': 849,
#        'name': 'Table Plates',
#        'code': 'AA18202010001',
#        'query': ':relevance:street:main:category:AA18202010001'},
#       {'count': 415,
#        'name': 'Dinner Plates',
#        'code': 'AA18202020001',
#        'query': ':relevance:street:main:category:AA18202020001'},
#       {'count': 201,
#        'name': 'Sauce Plates',
#        'code': 'AA18202030001',
#        'query': ':relevance:street:main:category:AA18202030001'},
#       {'count': 351,
#        'name': 'Trays',
#        'code': 'AA18202040001',
#        'query': ':relevance:street:main:category:AA18202040001'},
#       {'count': 358,
#        'name': 'Fruit Plates',
#        'code': 'AA18202050001',
#        'query': ':relevance:street:main:category:AA18202050001'}]},
#     {'count': 1796,
#      'name': 'Water Containers',
#      'code': 'AA18202500001',
#      'query': ':relevance:street:main:category:AA18202500001'},
#     {'count': 3818,
#      'name': 'Drinkware',
#      'code': 'AA18203000000',
#      'query': ':relevance:street:main:category:AA18203000000',
#      'subcats': [{'count': 2015,
#        'name': 'Water Cups & Glasses',
#        'code': 'AA18203010001',
#        'query': ':relevance:street:main:category:AA18203010001'},
#       {'count': 1095,
#        'name': 'Tea Cups',
#        'code': 'AA18203020001',
#        'query': ':relevance:street:main:category:AA18203020001'},
#       {'count': 1075,
#        'name': 'Coffee Mugs',
#        'code': 'AA18203030001',
#        'query': ':relevance:street:main:category:AA18203030001'},
#       {'count': 1026,
#        'name': 'Alcohol Drinkwares',
#        'code': 'AA18203040000',
#        'query': ':relevance:street:main:category:AA18203040000'}]},
#     {'count': 837,
#      'name': 'Wineware',
#      'code': 'AA18203500000',
#      'query': ':relevance:street:main:category:AA18203500000',
#      'subcats': [{'count': 325,
#        'name': 'Wine Openers',
#        'code': 'AA18203510001',
#        'query': ':relevance:street:main:category:AA18203510001'},
#       {'count': 126,
#        'name': 'Wine Decanters',
#        'code': 'AA18203520001',
#        'query': ':relevance:street:main:category:AA18203520001'},
#       {'count': 54,
#        'name': 'Wine Racks',
#        'code': 'AA18203530001',
#        'query': ':relevance:street:main:category:AA18203530001'},
#       {'count': 45,
#        'name': 'Wine Cabinet',
#        'code': 'AA18203540001',
#        'query': ':relevance:street:main:category:AA18203540001'},
#       {'count': 158,
#        'name': 'Wine Corks',
#        'code': 'AA18203550001',
#        'query': ':relevance:street:main:category:AA18203550001'},
#       {'count': 165,
#        'name': 'Ice Tongs & Stainless Ice Cubes',
#        'code': 'AA18203560001',
#        'query': ':relevance:street:main:category:AA18203560001'},
#       {'count': 81,
#        'name': 'Wine Buckets & Bags',
#        'code': 'AA18203570001',
#        'query': ':relevance:street:main:category:AA18203570001'},
#       {'count': 49,
#        'name': 'Wine Glass Labels',
#        'code': 'AA18203580001',
#        'query': ':relevance:street:main:category:AA18203580001'}]},
#     {'count': 4416,
#      'name': 'Food Warmers & Containers',
#      'code': 'AA18204000000',
#      'query': ':relevance:street:main:category:AA18204000000',
#      'subcats': [{'count': 1946,
#        'name': 'Food Containers',
#        'code': 'AA18204010001',
#        'query': ':relevance:street:main:category:AA18204010001'},
#       {'count': 946,
#        'name': 'Lunch Boxes',
#        'code': 'AA18204020001',
#        'query': ':relevance:street:main:category:AA18204020001'},
#       {'count': 254,
#        'name': 'Sealing Clips',
#        'code': 'AA18204030001',
#        'query': ':relevance:street:main:category:AA18204030001'},
#       {'count': 1451,
#        'name': 'Thermos Mugs & Bottles',
#        'code': 'AA18204040001',
#        'query': ':relevance:street:main:category:AA18204040001'},
#       {'count': 563,
#        'name': 'Thermos Food Jars',
#        'code': 'AA18204050001',
#        'query': ':relevance:street:main:category:AA18204050001'}]},
#     {'count': 684,
#      'name': 'Tea Sets',
#      'code': 'AA18204500000',
#      'query': ':relevance:street:main:category:AA18204500000',
#      'subcats': [{'count': 359,
#        'name': 'Tea Pots',
#        'code': 'AA18204510001',
#        'query': ':relevance:street:main:category:AA18204510001'},
#       {'count': 205,
#        'name': 'Tea Strainers',
#        'code': 'AA18204520001',
#        'query': ':relevance:street:main:category:AA18204520001'},
#       {'count': 315,
#        'name': 'Tea Sets',
#        'code': 'AA18204530001',
#        'query': ':relevance:street:main:category:AA18204530001'}]},
#     {'count': 570,
#      'name': 'Coffee Pots',
#      'code': 'AA18205000001',
#      'query': ':relevance:street:main:category:AA18205000001'},
#     {'count': 755,
#      'name': 'Table Cloths & Place Mats',
#      'code': 'AA18205500001',
#      'query': ':relevance:street:main:category:AA18205500001'},
#     {'count': 81,
#      'name': 'Cup Racks',
#      'code': 'AA18206000001',
#      'query': ':relevance:street:main:category:AA18206000001'},
#     {'count': 104,
#      'name': 'Napkins',
#      'code': 'AA18206500001',
#      'query': ':relevance:street:main:category:AA18206500001'},
#     {'count': 327,
#      'name': 'Coasters',
#      'code': 'AA18207000001',
#      'query': ':relevance:street:main:category:AA18207000001'},
#     {'count': 179,
#      'name': 'Toothpicks & Toothpick Holders',
#      'code': 'AA18207500000',
#      'query': ':relevance:street:main:category:AA18207500000',
#      'subcats': [{'count': 89,
#        'name': 'Toothpick',
#        'code': 'AA18207510001',
#        'query': ':relevance:street:main:category:AA18207510001'},
#       {'count': 115,
#        'name': 'Toothpick Holders',
#        'code': 'AA18207520001',
#        'query': ':relevance:street:main:category:AA18207520001'}]},
#     {'count': 1335,
#      'name': "Children's Tableware",
#      'code': 'AA18208000000',
#      'query': ':relevance:street:main:category:AA18208000000',
#      'subcats': [{'count': 532,
#        'name': "Children's Cutleries",
#        'code': 'AA18208010001',
#        'query': ':relevance:street:main:category:AA18208010001'},
#       {'count': 444,
#        'name': "Children's Bowls & Plates",
#        'code': 'AA18208020001',
#        'query': ':relevance:street:main:category:AA18208020001'},
#       {'count': 495,
#        'name': "Children's Cutleries Sets",
#        'code': 'AA18208030001',
#        'query': ':relevance:street:main:category:AA18208030001'}]},
#     {'count': 609,
#      'name': 'Disposable Tablewares',
#      'code': 'AA18208500000',
#      'query': ':relevance:street:main:category:AA18208500000',
#      'subcats': [{'count': 102,
#        'name': 'Disposable Chopsticks',
#        'code': 'AA18208510001',
#        'query': ':relevance:street:main:category:AA18208510001'},
#       {'count': 240,
#        'name': 'Disposable Bowls & Plates',
#        'code': 'AA18208520001',
#        'query': ':relevance:street:main:category:AA18208520001'},
#       {'count': 157,
#        'name': 'Disposable Cups',
#        'code': 'AA18208530001',
#        'query': ':relevance:street:main:category:AA18208530001'},
#       {'count': 169,
#        'name': 'Disposable Spoons & Forks',
#        'code': 'AA18208540001',
#        'query': ':relevance:street:main:category:AA18208540001'}]},
#     {'count': 106,
#      'name': 'Ashtray',
#      'code': 'AA18209000001',
#      'query': ':relevance:street:main:category:AA18209000001'},
#     {'count': 610,
#      'name': 'Tableware Sets',
#      'code': 'AA18209200001',
#      'query': ':relevance:street:main:category:AA18209200001'},
#     {'count': 314,
#      'name': 'Straws',
#      'code': 'AA18209400001',
#      'query': ':relevance:street:main:category:AA18209400001'},
#     {'count': 70,
#      'name': 'Dish Covers',
#      'code': 'AA18209600001',
#      'query': ':relevance:street:main:category:AA18209600001'},
#     {'count': 343,
#      'name': 'Lunch Bags',
#      'code': 'AA18209800001',
#      'query': ':relevance:street:main:category:AA18209800001'}]},
#   {'count': 20423,
#    'name': 'Bathroom',
#    'code': 'AA18250000000',
#    'query': ':relevance:street:main:category:AA18250000000',
#    'subcats': [{'count': 4363,
#      'name': 'Bath Linens',
#      'code': 'AA18250500000',
#      'query': ':relevance:street:main:category:AA18250500000',
#      'subcats': [{'count': 1659,
#        'name': 'Hand Towels',
#        'code': 'AA18250510001',
#        'query': ':relevance:street:main:category:AA18250510001'},
#       {'count': 2049,
#        'name': 'Face Towels',
#        'code': 'AA18250520001',
#        'query': ':relevance:street:main:category:AA18250520001'},
#       {'count': 1638,
#        'name': 'Bath Towels',
#        'code': 'AA18250530001',
#        'query': ':relevance:street:main:category:AA18250530001'},
#       {'count': 696,
#        'name': 'Hair Towels & Hair Turbans',
#        'code': 'AA18250540001',
#        'query': ':relevance:street:main:category:AA18250540001'},
#       {'count': 424,
#        'name': 'Bathrobes',
#        'code': 'AA18250550001',
#        'query': ':relevance:street:main:category:AA18250550001'}]},
#     {'count': 105,
#      'name': 'Bathroom Scales',
#      'code': 'AA18251000001',
#      'query': ':relevance:street:main:category:AA18251000001'},
#     {'count': 884,
#      'name': 'Shower Head & Hoses',
#      'code': 'AA18251500001',
#      'query': ':relevance:street:main:category:AA18251500001'},
#     {'count': 854,
#      'name': 'Toothbrush Holders & Cups',
#      'code': 'AA18252000001',
#      'query': ':relevance:street:main:category:AA18252000001'},
#     {'count': 2372,
#      'name': 'Hooks',
#      'code': 'AA18252500000',
#      'query': ':relevance:street:main:category:AA18252500000',
#      'subcats': [{'count': 707,
#        'name': 'Adhesive Hooks',
#        'code': 'AA18252510001',
#        'query': ':relevance:street:main:category:AA18252510001'},
#       {'count': 139,
#        'name': 'Suction Hooks',
#        'code': 'AA18252520001',
#        'query': ':relevance:street:main:category:AA18252520001'},
#       {'count': 1706,
#        'name': 'Wall Mounted Hooks',
#        'code': 'AA18252530001',
#        'query': ':relevance:street:main:category:AA18252530001'},
#       {'count': 68,
#        'name': 'S-Hooks',
#        'code': 'AA18252540001',
#        'query': ':relevance:street:main:category:AA18252540001'}]},
#     {'count': 1802,
#      'name': 'Shower Curtains',
#      'code': 'AA18253000001',
#      'query': ':relevance:street:main:category:AA18253000001'},
#     {'count': 3391,
#      'name': 'Bath Mats',
#      'code': 'AA18253500000',
#      'query': ':relevance:street:main:category:AA18253500000',
#      'subcats': [{'count': 2634,
#        'name': 'Slip-Proof Mat',
#        'code': 'AA18253510001',
#        'query': ':relevance:street:main:category:AA18253510001'},
#       {'count': 1209,
#        'name': 'Diatomaceous Earth Mat',
#        'code': 'AA18253520001',
#        'query': ':relevance:street:main:category:AA18253520001'},
#       {'count': 787,
#        'name': 'Slip-Proof Tub Mat',
#        'code': 'AA18253530001',
#        'query': ':relevance:street:main:category:AA18253530001'}]},
#     {'count': 440,
#      'name': 'Drain Cleansers',
#      'code': 'AA18254000000',
#      'query': ':relevance:street:main:category:AA18254000000',
#      'subcats': [{'count': 91,
#        'name': 'Toilet Plungers',
#        'code': 'AA18254010001',
#        'query': ':relevance:street:main:category:AA18254010001'},
#       {'count': 170,
#        'name': 'Drain Dissolving Cleaners',
#        'code': 'AA18254020001',
#        'query': ':relevance:street:main:category:AA18254020001'},
#       {'count': 216,
#        'name': 'Drain Hair Catchers',
#        'code': 'AA18254030001',
#        'query': ':relevance:street:main:category:AA18254030001'}]},
#     {'count': 1058,
#      'name': 'Soap Boxes & Trays',
#      'code': 'AA18254500001',
#      'query': ':relevance:street:main:category:AA18254500001'},
#     {'count': 4291,
#      'name': 'Bathroom Hooks',
#      'code': 'AA18255000001',
#      'query': ':relevance:street:main:category:AA18255000001'},
#     {'count': 227,
#      'name': 'Toilet Brushes',
#      'code': 'AA18255500001',
#      'query': ':relevance:street:main:category:AA18255500001'},
#     {'count': 576,
#      'name': 'Toilet Paper Holders',
#      'code': 'AA18256000001',
#      'query': ':relevance:street:main:category:AA18256000001'},
#     {'count': 323,
#      'name': 'Toilet Seats',
#      'code': 'AA18256500001',
#      'query': ':relevance:street:main:category:AA18256500001'},
#     {'count': 178,
#      'name': 'Toilet Seat Covers',
#      'code': 'AA18257000001',
#      'query': ':relevance:street:main:category:AA18257000001'},
#     {'count': 155,
#      'name': 'Shower Dispensers',
#      'code': 'AA18257500001',
#      'query': ':relevance:street:main:category:AA18257500001'},
#     {'count': 38,
#      'name': 'Spittoons',
#      'code': 'AA18258000001',
#      'query': ':relevance:street:main:category:AA18258000001'},
#     {'count': 237,
#      'name': 'Shower Caps',
#      'code': 'AA18258500001',
#      'query': ':relevance:street:main:category:AA18258500001'},
#     {'count': 342,
#      'name': 'Shower Sponges & Brushes',
#      'code': 'AA18259000001',
#      'query': ':relevance:street:main:category:AA18259000001'},
#     {'count': 531,
#      'name': 'Bathroom Fresheners',
#      'code': 'AA18259500000',
#      'query': ':relevance:street:main:category:AA18259500000',
#      'subcats': [{'count': 211,
#        'name': 'Bathroom Fresheners Spray',
#        'code': 'AA18259510001',
#        'query': ':relevance:street:main:category:AA18259510001'},
#       {'count': 339,
#        'name': 'Bathroom Deodorant Aroma',
#        'code': 'AA18259520001',
#        'query': ':relevance:street:main:category:AA18259520001'}]},
#     {'count': 4332,
#      'name': 'Bathroom Construction Materials',
#      'code': 'AA18259700000',
#      'query': ':relevance:street:main:category:AA18259700000',
#      'subcats': [{'count': 876,
#        'name': 'Bathtubs',
#        'code': 'AA18259710001',
#        'query': ':relevance:street:main:category:AA18259710001'},
#       {'count': 275,
#        'name': 'Bathroom Sinks',
#        'code': 'AA18259720001',
#        'query': ':relevance:street:main:category:AA18259720001'},
#       {'count': 283,
#        'name': 'Bathroom Cabinets & Storage',
#        'code': 'AA18259730001',
#        'query': ':relevance:street:main:category:AA18259730001'},
#       {'count': 108,
#        'name': 'Bathroom Tables',
#        'code': 'AA18259740001',
#        'query': ':relevance:street:main:category:AA18259740001'},
#       {'count': 1507,
#        'name': 'Bathroom Mirrors',
#        'code': 'AA18259750001',
#        'query': ':relevance:street:main:category:AA18259750001'},
#       {'count': 395,
#        'name': 'Bathroom Faucets',
#        'code': 'AA18259760001',
#        'query': ':relevance:street:main:category:AA18259760001'},
#       {'count': 76,
#        'name': 'Toilets',
#        'code': 'AA18259770001',
#        'query': ':relevance:street:main:category:AA18259770001'},
#       {'count': 1307,
#        'name': 'Others',
#        'code': 'AA18259780001',
#        'query': ':relevance:street:main:category:AA18259780001'}]}]},
#   {'count': 24093,
#    'name': 'Bedroom',
#    'code': 'AA18300000000',
#    'query': ':relevance:street:main:category:AA18300000000',
#    'subcats': [{'count': 3315,
#      'name': 'Mattresses',
#      'code': 'AA18301000000',
#      'query': ':relevance:street:main:category:AA18301000000',
#      'subcats': [{'count': 557,
#        'name': 'Spring Mattress',
#        'code': 'AA18301010001',
#        'query': ':relevance:street:main:category:AA18301010001'},
#       {'count': 154,
#        'name': 'Memory Foam mattress',
#        'code': 'AA18301020001',
#        'query': ':relevance:street:main:category:AA18301020001'},
#       {'count': 641,
#        'name': 'Latex Mattress',
#        'code': 'AA18301030001',
#        'query': ':relevance:street:main:category:AA18301030001'},
#       {'count': 750,
#        'name': 'Foldable Mattresses',
#        'code': 'AA18301040001',
#        'query': ':relevance:street:main:category:AA18301040001'},
#       {'count': 1306,
#        'name': 'Mattress Pads',
#        'code': 'AA18301050001',
#        'query': ':relevance:street:main:category:AA18301050001'},
#       {'count': 948,
#        'name': 'Mattress Protectors',
#        'code': 'AA18301060001',
#        'query': ':relevance:street:main:category:AA18301060001'}]},
#     {'count': 8940,
#      'name': 'Quilts',
#      'code': 'AA18302000000',
#      'query': ':relevance:street:main:category:AA18302000000',
#      'subcats': [{'count': 3690,
#        'name': 'Comforters',
#        'code': 'AA18302010001',
#        'query': ':relevance:street:main:category:AA18302010001'},
#       {'count': 440,
#        'name': 'Wool Comforters',
#        'code': 'AA18302020001',
#        'query': ':relevance:street:main:category:AA18302020001'},
#       {'count': 722,
#        'name': 'Down Quilts',
#        'code': 'AA18302030001',
#        'query': ':relevance:street:main:category:AA18302030001'},
#       {'count': 1350,
#        'name': 'Fleece Blanket',
#        'code': 'AA18302040001',
#        'query': ':relevance:street:main:category:AA18302040001'},
#       {'count': 29,
#        'name': 'Electric Blanket',
#        'code': 'AA18302050001',
#        'query': ':relevance:street:main:category:AA18302050001'},
#       {'count': 3431,
#        'name': 'Quilt Covers',
#        'code': 'AA18302060001',
#        'query': ':relevance:street:main:category:AA18302060001'},
#       {'count': 3398,
#        'name': 'Other Quilts',
#        'code': 'AA18302090001',
#        'query': ':relevance:street:main:category:AA18302090001'}]},
#     {'count': 7109,
#      'name': 'Pillows',
#      'code': 'AA18303000000',
#      'query': ':relevance:street:main:category:AA18303000000',
#      'subcats': [{'count': 542,
#        'name': 'Down & Feather Pillows',
#        'code': 'AA18303010001',
#        'query': ':relevance:street:main:category:AA18303010001'},
#       {'count': 1419,
#        'name': 'Polyester Pillows',
#        'code': 'AA18303020001',
#        'query': ':relevance:street:main:category:AA18303020001'},
#       {'count': 1969,
#        'name': 'Memory Foam Pillow',
#        'code': 'AA18303030001',
#        'query': ':relevance:street:main:category:AA18303030001'},
#       {'count': 4471,
#        'name': 'Bolster',
#        'code': 'AA18303040001',
#        'query': ':relevance:street:main:category:AA18303040001'},
#       {'count': 1239,
#        'name': 'Pillowcases',
#        'code': 'AA18303050001',
#        'query': ':relevance:street:main:category:AA18303050001'},
#       {'count': 619,
#        'name': 'Latex Pillows',
#        'code': 'AA18303060001',
#        'query': ':relevance:street:main:category:AA18303060001'}]},
#     {'count': 3985,
#      'name': 'Bed Sheets',
#      'code': 'AA18304000001',
#      'query': ':relevance:street:main:category:AA18304000001'},
#     {'count': 1160,
#      'name': 'Bed Mats',
#      'code': 'AA18305000001',
#      'query': ':relevance:street:main:category:AA18305000001'},
#     {'count': 5623,
#      'name': 'Bedding Sets',
#      'code': 'AA18306000001',
#      'query': ':relevance:street:main:category:AA18306000001'},
#     {'count': 2310,
#      'name': 'Pajamas',
#      'code': 'AA18307000001',
#      'query': ':relevance:street:main:category:AA18307000001'},
#     {'count': 2519,
#      'name': 'Slippers',
#      'code': 'AA18308000000',
#      'query': ':relevance:street:main:category:AA18308000000',
#      'subcats': [{'count': 2519,
# ...
#        'code': 'AA18555530001',
#        'query': ':relevance:street:main:category:AA18555530001'}]},
#     {'count': 805,
#      'name': 'Wall Stickers',
#      'code': 'AA18556000001',
#      'query': ':relevance:street:main:category:AA18556000001'},
#     {'count': 391,
#      'name': 'Paint',
#      'code': 'AA18556500001',
#      'query': ':relevance:street:main:category:AA18556500001'},
#     {'count': 1420,
#      'name': 'Feng Shui Products',
#      'code': 'AA18557000000',
#      'query': ':relevance:street:main:category:AA18557000000',
#      'subcats': [{'count': 1358,
#        'name': 'Feng Shui Decors',
#        'code': 'AA18557010001',
#        'query': ':relevance:street:main:category:AA18557010001'},
#       {'count': 152,
#        'name': 'Feng Shui Accessories',
#        'code': 'AA18557020001',
#        'query': ':relevance:street:main:category:AA18557020001'}]},
#     {'count': 336,
#      'name': 'Sofa & Chair Covers',
#      'code': 'AA18558000001',
#      'query': ':relevance:street:main:category:AA18558000001'},
#     {'count': 4,
#      'name': 'Ceramic Tiles',
#      'code': 'AA18558500001',
#      'query': ':relevance:street:main:category:AA18558500001'},
#     {'count': 51,
#      'name': 'Floors',
#      'code': 'AA18559000001',
#      'query': ':relevance:street:main:category:AA18559000001'}]},
#   {'count': 9121,
#    'name': 'Hardware & Tools',
#    'code': 'AA18600000000',
#    'query': ':relevance:street:main:category:AA18600000000',
#    'subcats': [{'count': 569,
#      'name': 'Universal Plugs & Power Strips',
#      'code': 'AA18600500000',
#      'query': ':relevance:street:main:category:AA18600500000',
#      'subcats': [{'count': 73,
#        'name': '3-pin Plugs',
#        'code': 'AA18600510001',
#        'query': ':relevance:street:main:category:AA18600510001'},
#       {'count': 438,
#        'name': 'Power Strips',
#        'code': 'AA18600520001',
#        'query': ':relevance:street:main:category:AA18600520001'},
#       {'count': 99,
#        'name': 'Plug Adapters',
#        'code': 'AA18600530001',
#        'query': ':relevance:street:main:category:AA18600530001'}]},
#     {'count': 3659,
#      'name': 'Rain Gears',
#      'code': 'AA18601000000',
#      'query': ':relevance:street:main:category:AA18601000000',
#      'subcats': [{'count': 2709,
#        'name': 'Umbrellas',
#        'code': 'AA18601010000',
#        'query': ':relevance:street:main:category:AA18601010000'},
#       {'count': 705,
#        'name': 'Raincoats',
#        'code': 'AA18601020001',
#        'query': ':relevance:street:main:category:AA18601020001'},
#       {'count': 411,
#        'name': 'Rain Boots',
#        'code': 'AA18601030001',
#        'query': ':relevance:street:main:category:AA18601030001'},
#       {'count': 80,
#        'name': 'Umbrella Stands',
#        'code': 'AA18601040001',
#        'query': ':relevance:street:main:category:AA18601040001'}]},
#     {'count': 281,
#      'name': 'Light Bulbs & Light Tubs',
#      'code': 'AA18601500000',
#      'query': ':relevance:street:main:category:AA18601500000',
#      'subcats': [{'count': 208,
#        'name': 'Light Bulbs',
#        'code': 'AA18601510001',
#        'query': ':relevance:street:main:category:AA18601510001'},
#       {'count': 37,
#        'name': 'Light Tubes',
#        'code': 'AA18601520001',
#        'query': ':relevance:street:main:category:AA18601520001'},
#       {'count': 38,
#        'name': 'Candle Light Bulbs',
#        'code': 'AA18601530001',
#        'query': ':relevance:street:main:category:AA18601530001'}]},
#     {'count': 325,
#      'name': 'Batteries',
#      'code': 'AA18602000000',
#      'query': ':relevance:street:main:category:AA18602000000',
#      'subcats': [{'count': 96,
#        'name': 'AA Battery',
#        'code': 'AA18602010001',
#        'query': ':relevance:street:main:category:AA18602010001'},
#       {'count': 66,
#        'name': 'AAA Battery',
#        'code': 'AA18602020001',
#        'query': ':relevance:street:main:category:AA18602020001'},
#       {'count': 16,
#        'name': 'Button Cell',
#        'code': 'AA18602030001',
#        'query': ':relevance:street:main:category:AA18602030001'},
#       {'count': 164,
#        'name': 'Other Battery',
#        'code': 'AA18602040001',
#        'query': ':relevance:street:main:category:AA18602040001'}]},
#     {'count': 14,
#      'name': 'Wire',
#      'code': 'AA18602500000',
#      'query': ':relevance:street:main:category:AA18602500000',
#      'subcats': [{'count': 14,
#        'name': 'Video Cable',
#        'code': 'AA18602510001',
#        'query': ':relevance:street:main:category:AA18602510001'}]},
#     {'count': 136,
#      'name': 'Sewing Kit',
#      'code': 'AA18603000001',
#      'query': ':relevance:street:main:category:AA18603000001'},
#     {'count': 226,
#      'name': 'Ladder',
#      'code': 'AA18603500001',
#      'query': ':relevance:street:main:category:AA18603500001'},
#     {'count': 171,
#      'name': 'Table & Chair Foot Cover',
#      'code': 'AA18604000001',
#      'query': ':relevance:street:main:category:AA18604000001'},
#     {'count': 245,
#      'name': 'Edge & Corner Guards',
#      'code': 'AA18604500001',
#      'query': ':relevance:street:main:category:AA18604500001'},
#     {'count': 213,
#      'name': 'Anti-slip Mat',
#      'code': 'AA18605000001',
#      'query': ':relevance:street:main:category:AA18605000001'},
#     {'count': 238,
#      'name': 'Shopping Trolley',
#      'code': 'AA18605500001',
#      'query': ':relevance:street:main:category:AA18605500001'},
#     {'count': 171,
#      'name': 'Air-conditioner Filter',
#      'code': 'AA18606000001',
#      'query': ':relevance:street:main:category:AA18606000001'},
#     {'count': 2734,
#      'name': 'Metal Tools & Hardware Tools',
#      'code': 'AA18606500000',
#      'query': ':relevance:street:main:category:AA18606500000',
#      'subcats': [{'count': 74,
#        'name': 'Torch',
#        'code': 'AA18606503001',
#        'query': ':relevance:street:main:category:AA18606503001'},
#       {'count': 339,
#        'name': 'Toolbox',
#        'code': 'AA18606506001',
#        'query': ':relevance:street:main:category:AA18606506001'},
#       {'count': 168,
#        'name': 'Electric Drill & Screwdriver',
#        'code': 'AA18606510001',
#        'query': ':relevance:street:main:category:AA18606510001'},
#       {'count': 195,
#        'name': 'Screwdriver & Screw',
#        'code': 'AA18606513001',
#        'query': ':relevance:street:main:category:AA18606513001'},
#       {'count': 106,
#        'name': 'Pliers',
#        'code': 'AA18606516001',
#        'query': ':relevance:street:main:category:AA18606516001'},
#       {'count': 59,
#        'name': 'Hammer',
#        'code': 'AA18606520001',
#        'query': ':relevance:street:main:category:AA18606520001'},
#       {'count': 69,
#        'name': 'Nail',
#        'code': 'AA18606526001',
#        'query': ':relevance:street:main:category:AA18606526001'},
#       {'count': 134,
#        'name': 'Lock',
#        'code': 'AA18606530001',
#        'query': ':relevance:street:main:category:AA18606530001'},
#       {'count': 45,
#        'name': 'Wrench',
#        'code': 'AA18606533001',
#        'query': ':relevance:street:main:category:AA18606533001'},
#       {'count': 90,
#        'name': 'Multi-Function Pliers',
#        'code': 'AA18606536001',
#        'query': ':relevance:street:main:category:AA18606536001'},
#       {'count': 118,
#        'name': 'Insulation Tape',
#        'code': 'AA18606540001',
#        'query': ':relevance:street:main:category:AA18606540001'},
#       {'count': 156,
#        'name': 'Mechanic Glove',
#        'code': 'AA18606543001',
#        'query': ':relevance:street:main:category:AA18606543001'},
#       {'count': 34,
#        'name': 'Safety Helmet',
#        'code': 'AA18606546001',
#        'query': ':relevance:street:main:category:AA18606546001'},
#       {'count': 471,
#        'name': 'Switch',
#        'code': 'AA18606550001',
#        'query': ':relevance:street:main:category:AA18606550001'},
#       {'count': 133,
#        'name': 'Doorbell',
#        'code': 'AA18606553001',
#        'query': ':relevance:street:main:category:AA18606553001'},
#       {'count': 146,
#        'name': 'Door Lock',
#        'code': 'AA18606556001',
#        'query': ':relevance:street:main:category:AA18606556001'},
#       {'count': 71,
#        'name': 'Water Tap',
#        'code': 'AA18606560001',
#        'query': ':relevance:street:main:category:AA18606560001'},
#       {'count': 174,
#        'name': 'Shower Edge Seal',
#        'code': 'AA18606566001',
#        'query': ':relevance:street:main:category:AA18606566001'},
#       {'count': 100,
#        'name': 'Measuring Tape',
#        'code': 'AA18606570001',
#        'query': ':relevance:street:main:category:AA18606570001'},
#       {'count': 88,
#        'name': 'Cable Tie',
#        'code': 'AA18606573001',
#        'query': ':relevance:street:main:category:AA18606573001'},
#       {'count': 304,
#        'name': 'Epoxy Glue &  Rapid Rubber Repair',
#        'code': 'AA18606576001',
#        'query': ':relevance:street:main:category:AA18606576001'},
#       {'count': 136,
#        'name': 'Mitred Bracket',
#        'code': 'AA18606580001',
#        'query': ':relevance:street:main:category:AA18606580001'}]},
#     {'count': 310,
#      'name': 'Door Holder',
#      'code': 'AA18607000001',
#      'query': ':relevance:street:main:category:AA18607000001'},
#     {'count': 15,
#      'name': 'Swiss Army Knives',
#      'code': 'AA18607500001',
#      'query': ':relevance:street:main:category:AA18607500001'},
#     {'count': 153,
#      'name': 'Personal Alarm',
#      'code': 'AA18608000001',
#      'query': ':relevance:street:main:category:AA18608000001'}]},
#   {'count': 8364,
#    'name': 'Stationery',
#    'code': 'AA18650000000',
#    'query': ':relevance:street:main:category:AA18650000000',
#    'subcats': [{'count': 1348,
#      'name': 'Pen',
#      'code': 'AA18650300000',
#      'query': ':relevance:street:main:category:AA18650300000',
#      'subcats': [{'count': 723,
#        'name': 'Pen',
#        'code': 'AA18650310001',
#        'query': ':relevance:street:main:category:AA18650310001'},
#       {'count': 168,
#        'name': 'Ink Pen',
#        'code': 'AA18650320001',
#        'query': ':relevance:street:main:category:AA18650320001'},
#       {'count': 114,
#        'name': 'Mechanical Pencil',
#        'code': 'AA18650330001',
#        'query': ':relevance:street:main:category:AA18650330001'},
#       {'count': 415,
#        'name': 'Color Pencil',
#        'code': 'AA18650340001',
#        'query': ':relevance:street:main:category:AA18650340001'}]},
#     {'count': 443,
#      'name': 'Correction Tape & Rubber',
#      'code': 'AA18650600001',
#      'query': ':relevance:street:main:category:AA18650600001'},
#     {'count': 845,
#      'name': 'Notebook',
#      'code': 'AA18651000001',
#      'query': ':relevance:street:main:category:AA18651000001'},
#     {'count': 286,
#      'name': 'Sticky Note',
#      'code': 'AA18651300001',
#      'query': ':relevance:street:main:category:AA18651300001'},
#     {'count': 355,
#      'name': 'Scissors & Cutters',
#      'code': 'AA18651600001',
#      'query': ':relevance:street:main:category:AA18651600001'},
#     {'count': 681,
#      'name': 'Tapes',
#      'code': 'AA18652300000',
#      'query': ':relevance:street:main:category:AA18652300000',
#      'subcats': [{'count': 159,
#        'name': 'Transparent Tape',
#        'code': 'AA18652310001',
#        'query': ':relevance:street:main:category:AA18652310001'},
#       {'count': 168,
#        'name': 'Packing Tape',
#        'code': 'AA18652320001',
#        'query': ':relevance:street:main:category:AA18652320001'},
#       {'count': 158,
#        'name': 'Double-sided Tape',
#        'code': 'AA18652330001',
#        'query': ':relevance:street:main:category:AA18652330001'},
#       {'count': 281,
#        'name': 'Multi-purpose Glue',
#        'code': 'AA18652340001',
#        'query': ':relevance:street:main:category:AA18652340001'}]},
#     {'count': 365,
#      'name': 'File Clip',
#      'code': 'AA18652600001',
#      'query': ':relevance:street:main:category:AA18652600001'},
#     {'count': 292,
#      'name': 'Envelope & Letter',
#      'code': 'AA18653000001',
#      'query': ':relevance:street:main:category:AA18653000001'},
#     {'count': 316,
#      'name': 'Pencil Case',
#      'code': 'AA18653600001',
#      'query': ':relevance:street:main:category:AA18653600001'},
#     {'count': 111,
#      'name': 'Pencil Sharpener',
#      'code': 'AA18654000001',
#      'query': ':relevance:street:main:category:AA18654000001'},
#     {'count': 141,
#      'name': 'Mouse Pad',
#      'code': 'AA18654300001',
#      'query': ':relevance:street:main:category:AA18654300001'},
#     {'count': 117,
#      'name': 'Notice Board & Accessories',
#      'code': 'AA18654600001',
#      'query': ':relevance:street:main:category:AA18654600001'},
#     {'count': 1100,
#      'name': 'Art & Craft',
#      'code': 'AA18655000001',
#      'query': ':relevance:street:main:category:AA18655000001'},
#     {'count': 373,
#      'name': 'Calendar',
#      'code': 'AA18655300001',
#      'query': ':relevance:street:main:category:AA18655300001'},
#     {'count': 156,
#      'name': 'Magnet',
#      'code': 'AA18655600001',
#      'query': ':relevance:street:main:category:AA18655600001'},
#     {'count': 74,
#      'name': 'Calculator',
#      'code': 'AA18656000001',
#      'query': ':relevance:street:main:category:AA18656000001'},
#     {'count': 41,
#      'name': 'Rope',
#      'code': 'AA18656300001',
#      'query': ':relevance:street:main:category:AA18656300001'},
#     {'count': 232,
#      'name': 'File & Book Stand',
#      'code': 'AA18656600001',
#      'query': ':relevance:street:main:category:AA18656600001'},
#     {'count': 1978,
#      'name': 'Other Stationery',
#      'code': 'AA18657000001',
#      'query': ':relevance:street:main:category:AA18657000001'}]},
#   {'count': 1780,
#    'name': 'Gardenware',
#    'code': 'AA18700000000',
#    'query': ':relevance:street:main:category:AA18700000000',
#    'subcats': [{'count': 1069,
#      'name': 'Garden Tools',
#      'code': 'AA18701000000',
#      'query': ':relevance:street:main:category:AA18701000000',
#      'subcats': [{'count': 710,
#        'name': 'Flower Pot & Rack',
#        'code': 'AA18701010001',
#        'query': ':relevance:street:main:category:AA18701010001'},
#       {'count': 335,
#        'name': 'Watering Can & Water Sprayer',
#        'code': 'AA18701020001',
#        'query': ':relevance:street:main:category:AA18701020001'},
#       {'count': 129,
#        'name': 'Garden Shovel',
#        'code': 'AA18701030001',
#        'query': ':relevance:street:main:category:AA18701030001'}]},
#     {'count': 711,
#      'name': 'Plants',
#      'code': 'AA18702000001',
#      'query': ':relevance:street:main:category:AA18702000001'},
#     {'count': 310,
#      'name': 'Preserved Flower',
#      'code': 'AA18703000001',
#      'query': ':relevance:street:main:category:AA18703000001'}]},
#   {'count': 2669,
#    'name': 'Festive Supplies',
#    'code': 'AA18750000000',
#    'query': ':relevance:street:main:category:AA18750000000',
#    'subcats': [{'count': 1061,
#      'name': 'Chinese New Year',
#      'code': 'AA18751000000',
#      'query': ':relevance:street:main:category:AA18751000000',
#      'subcats': [{'count': 545,
#        'name': 'Red Packet',
#        'code': 'AA18751010001',
#        'query': ':relevance:street:main:category:AA18751010001'},
#       {'count': 287,
#        'name': 'Fai Chun',
#        'code': 'AA18751020001',
#        'query': ':relevance:street:main:category:AA18751020001'},
#       {'count': 568,
#        'name': 'Chinese New Year Decor',
#        'code': 'AA18751030001',
#        'query': ':relevance:street:main:category:AA18751030001'},
#       {'count': 32,
#        'name': 'Confectionery Box',
#        'code': 'AA18751040001',
#        'query': ':relevance:street:main:category:AA18751040001'}]},
#     {'count': 328,
#      'name': 'Birthday Candle',
#      'code': 'AA18753000001',
#      'query': ':relevance:street:main:category:AA18753000001'},
#     {'count': 268,
#      'name': 'Mahjong & Accessories',
#      'code': 'AA18755000001',
#      'query': ':relevance:street:main:category:AA18755000001'},
#     {'count': 111,
#      'name': 'Poker & Chips',
#      'code': 'AA18756000001',
#      'query': ':relevance:street:main:category:AA18756000001'},
#     {'count': 933,
#      'name': 'Balloons',
#      'code': 'AA18757000001',
#      'query': ':relevance:street:main:category:AA18757000001'}]}]}

# %%
'subcats' in cat['categories'][0]['subcats'][1]['subcats'][0].keys()
# Out:
# True

# %%
uu = "https://www.hktvmall.com/hktvwebservices/v1/hktv/search_products_v2?query=%3Arelevance%3Astreet%3Amain%3Acategory%3AAA16000000000&lang=en&currentPage=0&pageSize=24000&user_id=anonymous"
head = {
    "accept-encoding":"gzip",
"authorization":"Bearer 2de2ea56-4e3c-4401-9a76-c014c70bdc08",
"connection":"Keep-Alive",
"cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=0B05C4127AB75E4CFED31284A948BB10",
"device-type":"android",
"host":"www.hktvmall.com",
"ott-uuid":"e04d5772-cb0f-4356-acd5-96819447eb2d",
"user-agent":"okhttp/2.2.0"
}

# %%
produ = requests.get(uu,headers= head).json()

# %%
len(produ['products'])
# Out:
# 1000

# %%
products_page_url_base = "https://www.hktvmall.com/hktvwebservices/v1/hktv/search_products_v2?query="

all_pages = []
for category in cat['categories'] :
    
    if 'subcats' in category.keys():        
        for subcat1 in category['subcats']:
            
            if 'subcats' in subcat1.keys():
                for subcat2 in subcat1['subcats']:
                    
                    if 'subcats' in subcat2.keys():                     
                        for subcat3 in subcat2['subcats']:
                            all_pages.append(subcat3)
                    
                    else:
                        all_pages.append(subcat2)                    
            else:
                all_pages.append(subcat1)
    else :
        all_pages.append(category)

# %%
all_pages_links = []

for pg in all_pages:
    all_pages_links.append(products_page_url_base+urllib.parse.quote(pg['query'])+"&lang=en&currentPage=0&pageSize=100000&user_id=anonymous")

# %%
tes = requests.get(all_pages_links[0],headers=headers).json()

# %%
tes['products'][0]
# Out:
# {'code': 'H1888001_S_16005842',
#  'name': 'froq Plastic Storage Box with Lid (M) - White',
#  'url': 'main/%E6%97%A5%E3%81%AE%E9%9B%9C%E8%B2%A8-Zakka-Home/s/H1888003/Housewares/Housewares/Storage-%26-Organisation/Plastic-Storage-Container/froq-Plastic-Storage-Box-with-Lid-M-White/p/H1888001_S_16005842',
#  'description': 'The cover can also be removed and washed, and the door can be removed with a single push. Easy to clean storage box <br> <br>For details, please refer to the label on the product. <br>The picture above is for reference only. The real object should be considered as final.',
#  'purchasable': True,
#  'stock': {'stockLevelStatus': {'code': 'inStock', 'codeLowerCase': 'instock'},
#   'stockLevel': 1,
#   'consignmentWarehouse': False,
#   'forceInStock': False},
#  'averageRating': 5.0,
#  'numberOfReviews': 5,
#  'summary': 'Made in Japan <br> <br>Size : 385x460x310Hmm <br> <br>Modular design, can be stacked for easy storage <br> <br>4 ways open lid',
#  'price': {'currencyIso': 'HKD',
#   'priceType': 'BUY',
#   'value': '289.0',
#   'membershipLevel': 'NORMAL',
#   'formattedValue': '$ 289.00'},
#  'baseProduct': 'H188800116005842-6',
#  'images': [{'imageType': 'PRIMARY',
#    'format': 'product',
#    'url': '//images.hktvmall.com/h1888001/271154/h1888001_16005842_211102105646_01_300.jpg'}],
#  'categories': [{'code': 'AA18051500001', 'sequence': 0}],
#  'potentialPromotions': [{'code': 'Fixed Price - H1888001_20220328_FixedPrice[179.0]_16005842_sys',
#    'promotionType': 'HktvProductPercentageDiscountPromotion',
#    'startDate': '2015-01-01T00:00:00+08:00',
#    'endDate': '2099-01-01T23:59:59+08:00',
#    'description': 'Discount to $179.0',
#    'priority': 95,
#    'percentage': 38.06228,
#    'percentageDiscountRow': [{'discount': 38.06228,
#      'customerType': 'NORMAL',
#      'priority': 0,
#      'description': 'Discount to $179.0'}],
#    'creationTime': '2022-03-28 09:25:04.0 UTC'},
#   {'code': 'Redemption_H1888001_Freshdisc1',
#    'promotionType': 'HKTV Product Threshold Perfect Partner Promotion (Store based)',
#    'startDate': '2022-05-07T00:00:00+08:00',
#    'endDate': '2022-05-23T00:00:00+08:00',
#    'description': 'Redemption_H1888001_Freshdisc1',
#    'priority': 77,
#    'percentage': 0.0,
#    'creationTime': '2022-05-07 03:41:06.0 UTC'}],
#  'score': 1.0,
#  'brandName': 'SANKA',
#  'storeCode': 'H1888003',
#  'storeCodeOriginal': 'H1888001',
#  'storeName': '日の雜貨 Zakka Home',
#  'storeType': 'hktv_own_store',
#  'storeTypeDisplay': 'HKTV owned store',
#  'storeRating': 4.5,
#  'chineseLocaleActive': False,
#  'deliveryModeName': 'HKTV Standard Delivery',
#  'deliveryModeCode': 'hktv-standard-delivery',
#  'packingSpec': '1 pc',
#  'countryOfOrigin': 'Japan',
#  'numberOfColors': 5,
#  'storeTC': '<p>&bull; This product is sold to you by HKTVmall.<br /><br />&bull; In situation where there are limitations, price, promotion offers and other marketing campaigns on the HKTVmall may varies from retail stores, the terms and offers are only applicable to HKTVmall.<br /><br />&bull; Our store will protect your personal Information in accordance with the relevant provisions of the Personal Data (Privacy) Ordinance and in accordance with HKTVmall Privacy Policies.<br /><br />&bull; Colour shown may be slightly different than actual products.<br /><br />&bull; In the event of dispute, HKTVmall&#39;s decision shall be final and conclusive.</p>',
#  'promotionPrice': {'currencyIso': 'HKD',
#   'priceType': 'DISCOUNT',
#   'value': '179.0',
#   'formattedValue': '$ 179.00'},
#  'labels': [{'type': 'OFFER', 'name': 'Discount to $179.0'},
#   {'type': 'REBATE',
#    'name': '0% Rewards',
#    'amount': 0.0,
#    'loyaltyPoint': '0'}],
#  'loyaltyPoint': '0.0',
#  'priceList': [{'currencyIso': 'HKD',
#    'priceType': 'BUY',
#    'value': '289.0',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 289.00'},
#   {'currencyIso': 'HKD',
#    'priceType': 'DISCOUNT',
#    'value': '179.00001079999998',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 179.00'}],
#  'colors': [{'colorName': 'WHITE', 'colorValue': ''},
#   {'colorName': 'Default', 'colorValue': ''},
#   {'colorName': 'GREEN', 'colorValue': ''},
#   {'colorName': 'GREY', 'colorValue': ''},
#   {'colorName': 'BROWN', 'colorValue': ''},
#   {'colorName': 'BLUE', 'colorValue': ''}],
#  'promotionText': '',
#  'promotionStyle': 'GREY',
#  'invisible': False,
#  'recommendedPrice': {'name': '',
#   'fontColor': '#000000',
#   'fontBgColor': '#FFFFFF',
#   'hasStrikeThrough': True},
#  'savedPrice': [{'currencyIso': 'HKD',
#    'priceType': 'DISCOUNT',
#    'value': '109.99998920000002',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 110.00'}],
#  'productKeyword': 'V03809',
#  'primaryCatCode': 'AA18050500001',
#  'isFlashSale': False,
#  'isEcoupon': False,
#  'numberOfVariants': 5,
#  'isStockNotified': False,
#  'urgent': False,
#  'purchaseOption': 0,
#  'reservable': False,
#  'quantity': 0,
#  'perfectPartnerPromotion': {'code': 'Redemption_H1888001_Freshdisc1',
#   'name': 'The House redemption!',
#   'label': 'Redeem ToiletDuck Refill',
#   'description': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45) <br>The promotion is valid till 22-MAY-2022<br>Only available while stock lasts.',
#   'shortDescription': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45)',
#   'colorCode': '#CC0000',
#   'discountType': 'QUANTITY',
#   'startTime': 1651852800000,
#   'endTime': 1653235200000},
#  'userMax': 0,
#  'store': {'code': 'H1888003', 'name': '日の雜貨 Zakka Home'},
#  'deliveryLabel': {'deliveryMode': 'standard-express',
#   'name': 'Earliest 1 Day',
#   'bgColor': '#D8F7C5'},
#  'includeRemovalService': False,
#  'isInsurance': False,
#  'salesNumberString': '200+ Sold',
#  'packingLength': 0.0,
#  'packingHeight': 0.0,
#  'packingDepth': 0.0,
#  'specialAddCartFlowLink': '',
#  'marketingLabelUids': [],
#  'videos': {'galleryUrls': []},
#  'presellSku': False,
#  'inStorePickUpCheckoutLink': '',
#  'isLiteAppExcluded': False,
#  'salesVolume': 228}

# %%
https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?
    product_id=H0888001_S_10003577B
    &
    lang=en&no_stock_redirect=true&user_id=anonymous

# %%
all_products_links = []
for i,lnk in enumerate(all_pages_links) :
    multiple_prod_pg = requests.get(lnk,headers=headers).json()
    
    for prd in multiple_prod_pg['products']:
        all_products_links.append(prd)
        sys.stdout.write("\rDoing thing %i /495" % i)
        sys.stdout.flush()
# Out:
# Doing thing 2 /495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/897449181.py in <module>
#       1 all_products_links = []
#       2 for i,lnk in enumerate(all_pages_links) :
# ----> 3     multiple_prod_pg = requests.get(lnk,headers=headers).json()
#       4
#       5     for prd in multiple_prod_pg['products']:
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\python\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\python\python39\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\python\python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\python\python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
for i,pr_lnk in enumerate(all_products_links):
    url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = head).json())
    sys.stdout.write("\rDoing thing %i /495000" % i)
    sys.stdout.flush()
# Out:
# Doing thing 10 /495000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/1284334702.py in <module>
#       3 for i,pr_lnk in enumerate(all_products_links):
#       4     url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ----> 5     products.append(requests.get(url,headers = head).json())
#       6     sys.stdout.write("\rDoing thing %i /495000" % i)
#       7     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\python\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\python\python39\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\python\python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\python\python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
products[3]
# Out:
# {'code': 'H1888001_S_16003423',
#  'name': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#  'description': '',
#  'purchasable': True,
#  'stock': {'stockLevelStatus': {'code': 'inStock', 'codeLowerCase': 'instock'},
#   'stockLevel': 16,
#   'consignmentWarehouse': True,
#   'forceInStock': False},
#  'averageRating': 3.8,
#  'numberOfReviews': 119,
#  'summary': '550x390x330mm (48L)<br><br><br><br>3pcs/pack<br><br><br><br>Transparent Pink Lid w/Pink Handle <br><br><br><br>Product is make by imported PP (polypropylene) which is safe, ECO<br><br><br><br>Stackable <br><br><br><br>Easy locking lid',
#  'price': {'currencyIso': 'HKD',
#   'priceType': 'BUY',
#   'value': '299.0',
#   'membershipLevel': 'NORMAL',
#   'formattedValue': '$ 299.00'},
#  'baseProduct': 'H188800116003423',
#  'images': [{'imageType': 'PRIMARY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)'},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 0},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 1},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 2},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 3},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 4},
#   {'imageType': 'GALLERY',
#    'format': 'superZoom',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_1200.jpg',
#    'altText': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'galleryIndex': 5}],
#  'categories': [{'code': 'ZZ00000109324',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000109324',
#    'sequence': 0},
#   {'code': 'ZZ00000092128',
#    'url': '/main/Promotion-Product-Category/The-House-Products/c/ZZ00000092128',
#    'sequence': 0},
#   {'code': 'ZZ00000060830',
#    'url': '/main/Promotion-Product-Category/Purchase-Home-base-items-2-pcs-get-15%25off%21/c/ZZ00000060830',
#    'sequence': 0},
#   {'code': 'ZZ00000047488',
#    'url': '/main/Promotion-Product-Category/The-House-Product/c/ZZ00000047488',
#    'sequence': 0},
#   {'code': 'ZZ00000025334',
#    'url': '/main/Promotion-Product-Category/Home-Base-48L-storage-box-for-20%25off%21/c/ZZ00000025334',
#    'sequence': 0},
#   {'code': 'ZZ00000028586',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000028586',
#    'sequence': 0},
#   {'code': 'ZZ00000028747',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000028747',
#    'sequence': 0},
#   {'code': 'ZZ00000029769',
#    'url': '/main/Promotion-Product-Category/The-House-products/c/ZZ00000029769',
#    'sequence': 0},
#   {'code': 'ZZ00000032663',
#    'url': '/main/Promotion-Product-Category/The-House-product/c/ZZ00000032663',
#    'sequence': 0},
#   {'code': 'ZZ00000035544',
#    'url': '/main/Promotion-Product-Category/The-House-product/c/ZZ00000035544',
#    'sequence': 0},
#   {'code': 'ZZ00000036851',
#    'url': '/main/Promotion-Product-Category/Thankful-Cross-store-Buy-2-Enjoy-15%25-OFF/c/ZZ00000036851',
#    'sequence': 0},
#   {'code': 'ZZ00000046256',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000046256',
#    'sequence': 0},
#   {'code': 'ZZ00000048698',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000048698',
#    'sequence': 0},
#   {'code': 'ZZ00000048526',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000048526',
#    'sequence': 0},
#   {'code': 'ZZ00000050897',
#    'url': '/main/Promotion-Product-Category/The-House-product/c/ZZ00000050897',
#    'sequence': 0},
#   {'code': 'ZZ00000050899',
#    'url': '/main/Promotion-Product-Category/The-House-product/c/ZZ00000050899',
#    'sequence': 0},
#   {'code': 'ZZ00000052927',
#    'url': '/main/Promotion-Product-Category/Purchase-Home-Base-Product-2pcs-get-20%25-off%21/c/ZZ00000052927',
#    'sequence': 0},
#   {'code': 'ZZ00000050942',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000050942',
#    'sequence': 0},
#   {'code': 'ZZ00000053929',
#    'url': '/main/Promotion-Product-Category/The-House-product/c/ZZ00000053929',
#    'sequence': 0},
#   {'code': 'ZZ00000099868',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000099868',
#    'sequence': 0},
#   {'code': 'ZZ00000099871',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000099871',
#    'sequence': 0},
#   {'code': 'ZZ00000101654',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000101654',
#    'sequence': 0},
#   {'code': 'ZZ00000107996',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000107996',
#    'sequence': 0},
#   {'code': 'ZZ00000109990',
#    'url': '/main/Promotion-Product-Category/FreeGiftPromotion-Category/c/ZZ00000109990',
#    'sequence': 0},
#   {'code': 'ZZ00000110928',
#    'url': '/main/Promotion-Product-Category/The-House/c/ZZ00000110928',
#    'sequence': 0},
#   {'code': 'ZZ00000110961',
#    'url': '/main/Promotion-Product-Category/The-House/c/ZZ00000110961',
#    'sequence': 0}],
#  'potentialPromotions': [{'code': 'Fixed Price - H1888001_20211213_FixedPrice[169.0]_16003423_sys',
#    'promotionType': 'HktvProductPercentageDiscountPromotion',
#    'startDate': '2022-04-23T00:00:00+08:00',
#    'endDate': '2099-01-01T23:59:59+08:00',
#    'description': 'Discount to $169.0',
#    'priority': 95,
#    'percentage': 43.47826,
#    'percentageDiscountRow': [{'discount': 43.47826,
#      'customerType': 'NORMAL',
#      'priority': 0,
#      'description': 'Discount to $169.0'}],
#    'creationTime': '2021-12-13 06:48:04.0 UTC'},
#   {'code': 'Redemption_H1888001_Freshdisc1',
#    'promotionType': 'HKTV Product Threshold Perfect Partner Promotion (Store based)',
#    'startDate': '2022-05-07T00:00:00+08:00',
#    'endDate': '2022-05-23T00:00:00+08:00',
#    'description': 'Redemption_H1888001_Freshdisc1',
#    'priority': 77,
#    'percentage': 0.0,
#    'creationTime': '2022-05-07 03:41:06.0 UTC'}],
#  'baseOptions': [{'variantType': 'HktvVariantProduct',
#    'options': [{'code': 'H1888001_S_16003423',
#      'stock': {'stockLevelStatus': {'code': 'inStock',
#        'codeLowerCase': 'instock'},
#       'stockLevel': 16,
#       'consignmentWarehouse': True,
#       'forceInStock': False},
#      'url': '/p/H1888001_S_16003423',
#      'variantOptionQualifiers': []}],
#    'selected': {'code': 'H1888001_S_16003423',
#     'stock': {'stockLevelStatus': {'code': 'inStock',
#       'codeLowerCase': 'instock'},
#      'stockLevel': 16,
#      'consignmentWarehouse': True,
#      'forceInStock': False},
#     'url': '/p/H1888001_S_16003423',
#     'variantOptionQualifiers': []},
#    'qualifierNames': []}],
#  'brandName': 'Home Base',
#  'pickupdays': '1/2/3/4/5/6/7',
#  'pickUpTimeslot': 'AM/PM/EV',
#  'storeCode': 'H1888001',
#  'storeCodeOriginal': 'H1888001',
#  'storeName': 'The House',
#  'storeType': 'hktv_own_store',
#  'storeTypeDisplay': 'HKTV owned store',
#  'storeRating': 4.5,
#  'readyPickupDays': '0',
#  'readyPickupHours': '0',
#  'deliveryModeName': 'HKTV Standard Delivery',
#  'deliveryModeCode': 'hktv-standard-delivery',
#  'storeDescription': '',
#  'deliveryRemarkFullMsg': '* The product can be arranged to deliver within 24 hours the soonest when the order is placed',
#  'packingSpec': '48L x 3pcs',
#  'countryOfOrigin': 'China',
#  'photosTabImages': [{'format': '1200Wx1200H',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180907043417_other_07_1200.jpg'},
#   {'format': '1200Wx1200H',
#    'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180907043424_other_08_1200.jpg'}],
#  'numberOfColors': 0,
#  'storeTC': '<p>&bull; This product is sold to you by HKTVmall.<br /><br />&bull; In situation where there are limitations, price, promotion offers and other marketing campaigns on the HKTVmall may varies from retail stores, the terms and offers are only applicable to HKTVmall.<br /><br />&bull; Our store will protect your personal Information in accordance with the relevant provisions of the Personal Data (Privacy) Ordinance and in accordance with HKTVmall Privacy Policies.<br /><br />&bull; Colour shown may be slightly different than actual products.<br /><br />&bull; In the event of dispute, HKTVmall&#39;s decision shall be final and conclusive.</p>',
#  'deliveryOrReturnPolicy': '<p>The &#39;Merchant Delivery&#39; goods delivered by this store cannot be combined with goods delivered by other merchants to calculate delivery fee. Spend $400 on &#39;Merchant Delivery&#39; goods at this store to enjoy free delivery, otherwise the delivery fee is $80. Some remote areas require additional delivery fee, please contact merchant directly for details.<br />Below are remote areas for your reference:<br />Tuen Mun Town Centre, Siu Chi, Siu Tsui, On Ting, Yau Oi South, Yau Oi North, Tsui Hing, Shan King, King Lung, Hing Chak, San Hui, Sam Shing, Hanford, Fu Sun, Yuet Wu, Siu Hei, Wu King, Butterfly, Lok Tsui, Lung Mun, San King, Leung King, Tin King, Po Tin, Kin Sang, Siu Hong, Prime View, Fu Tai, Tuen Mun Rural, Fung Nin, Shui Pin, Nam Ping, Pek Long, Yuen Long Centre, Yuen Lung, Fung Cheung, Shap Pat Heung East, Shap Pat Heung Central, Shap Pat Heung West, Ping Shan South, Ping Shan Central, Ping Shan North, Ha Tsuen, Tin Shing, Shui Oi, Shui Wa, Chung Wah, Yuet Yan, Fu Yan, Yat Chak, Tin Heng, Wang Yat, Ching King, Kingswood North, Tsz Yau, Yiu Yau, Tin Yiu, Kingswood South, Chung Pak, Fairview Park, San Tin, Kam Tin, Pat Heung North, Pat Heung South, Luen Wo Hui, Fan Ling Town, Cheung Wah, Wah Do, Wah Ming, Yan Shing, Shing Fuk, Fanling South, Ching Ho, Yu Tai, Sheung Shui Rural, Choi Yuen Shek Wu Hui, Tin Ping West, Fung Tsui, Sha Ta, Tin Ping East, Queen&#39;s Hill, Tai Po Hui, Tai Po Central, Chung Ting, Tai Yuen, Fu Heng, Yee Fu, Fu Ming Sun, Kwong Fuk &amp; Plover Cove, Wang Fuk, Tai Po Kau, Wan Tau Tong, San Fu, Lam Tsuen Valley, Po Nga, Tai Wo, Old Market &amp; Serenity, Hong Lok Yuen, Shuen Wan, Sai Kung North, Sai Kung Central, Pak Sha Wan, Sai Kung Islands, Hang Hau East, Hang Hau West, Po Yee, Wai King, Do Shin, Kin Ming, Choi Kin, O Tong, Fu Kwan, Kwan Po, Nam On, Hong King, Tsui Lam, Po Lam, Yan Ying, Wan Hang, King Lam, Hau Tak, Fu Nam, Tak Ming, Sheung Tak, Kwong Ming, Wan Po North, Wan Po South, Lantau, Yat Tung Estate North, Yat Tung Estate South, Tung Chung North, Tung Chung South, Discovery Bay, Peng Chau &amp; Hei Ling Chau,. Lamma &amp; Po Toi, Cheung Chau South, Cheung Chau North</p><p>&bull; Our products will be delivered by HKTVmall, please refer to Shipping Information for more details.</p><p>&nbsp;</p><p>&nbsp;</p><p>&bull; Actual delivery time depends on the products ordered and the shipping time of the particular merchants.<br /><br />&bull; Shipping time of this store: Monday to Sunday, including Public Holiday, 9am and 3pm</p><p>&nbsp;</p><p>&nbsp;</p><p>&nbsp;</p><p>&nbsp;</p><p>&bull; All products are non-returnable.<br /><br />&bull; In the event of dispute, HKTVmall&#39;s decision shall be final and conclusive.</p><p>&nbsp;</p><p>&nbsp;</p><p>&nbsp;</p><p>&nbsp;</p><p>&bull; However, if you received a product that is damaged or defective, please contact HKTVmall Customer Service within 7 days.</p><p>&nbsp;</p>',
#  'storeLogo': {'url': '//images.hktvmall.com/h1888001/h1888001_mobilelogo_171009090059.jpg'},
#  'recommendation': [{'code': 'H1888001_S_16004712',
#    'name': '3 Tier Plastic Multi-purpose Kitchen Rack',
#    'averageRating': 4.3,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/737a910c27751e401416ae838a772297793f8959/h1888001_16004712_190121102847_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '159.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 159.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '98.9999985',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 99.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16002958',
#    'name': 'Storage Container with Wheels (Blue) (Body, Cover)',
#    'averageRating': 4.3,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/ce1040b1d52eff646c5618d5c47de55551fb65e0/h1888001_16002958_180626041604_01_300.jpg'}],
#    'brandName': 'Red-A',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '329.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 329.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '204.9999987',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 205.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003989',
#    'name': 'froq Plastic Storage Box with Lid (M) - Blue',
#    'averageRating': 4.2,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/3a483db8613e831a0861a3852ec13740e61b2337/h1888001_16003989_181010011934_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '289.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 289.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '179.00001079999998',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 179.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004206',
#    'name': 'Plasctic Storage Box with Lid and Handle (3.4L)',
#    'averageRating': 4.2,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/3a8544e883a36e5c662981410583f4835062cb6a/h1888001_16004206_181006053107_01_300.jpg'}],
#    'brandName': 'Fudo Giken',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '85.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 85.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '54.999998000000005',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 55.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003423',
#    'name': 'Plastic Storage Box with Lid & Wheels-Pink Lid & Handle (For Delivery Only)',
#    'averageRating': 3.8,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_300.jpg'}],
#    'brandName': 'Home Base',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '299.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 299.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '169.00000260000002',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 169.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004714',
#    'name': '2 Tier Plastic Multi-purpose Kitchen Rack',
#    'averageRating': 4.0,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/42b494a753863c51889ff937bf3f661c24a9afde/h1888001_16004714_190121103015_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '205.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 205.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '125.0000005',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 125.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005227',
#    'name': "Lock'in Pod Plastic Storage Box with Lid (M)",
#    'averageRating': 4.3,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/9d7cc4dfd8eb409f8ea77c9c1b0eb912ff9df011/h1888001_16005227_200416025504_01_300.jpg'}],
#    'brandName': 'JEJ',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '389.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 389.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '239.0000051',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 239.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005790',
#    'name': "Room's Convesso Self-Assembly 4 Layer Plastic Drawer Cabinet - White (340W x 445D x 875Hmm)",
#    'averageRating': 5.0,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/268937/h1888001_16005790_210812042210_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '1119.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 1,119.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '699',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 699.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005847',
#    'name': 'froq Plastic Storage Box with Lid (L) -  Dark Brown',
#    'averageRating': 4.7,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/271154/h1888001_16005847_211102110041_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '479.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 479.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '298.9999909',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 299.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_B16002042',
#    'name': 'Container Box W/ Wheels (25L) - Cover+Body',
#    'averageRating': 4.1,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/153390/h1888001_b16002042_180205035641_01_300.jpg'}],
#    'brandName': 'KEYWAY',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '109.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 109.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '68.9999975',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 69.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004812',
#    'name': 'Floor-to-Ceiling Single Pole Metal Extendable Hanger',
#    'averageRating': 3.5,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/91e8aa818dd41cd9c622d732df9422a51d7cd495/h1888001_16004812_190321114650_01_300.jpg'}],
#    'brandName': 'YLT',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '299.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 299.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '188.999993',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 189.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005468',
#    'name': 'Metal Storage Basket',
#    'averageRating': 4.2,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/257832/h1888001_16005468_200618044834_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '49.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 49.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '28.999998299999998',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 29.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003991',
#    'name': 'froq Plastic Storage Box with Lid (L) - Transparent White',
#    'averageRating': 3.9,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/8a35a9e93d675c717e5a31b655d9d375ead64eda/h1888001_16003991_181010012400_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '479.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 479.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '298.9999909',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 299.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003981',
#    'name': 'froq Plastic Storage Box with Lid (S) - Transparent White',
#    'averageRating': 4.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/4961e61e1e21e80777312b3c43b8e8151078c499/h1888001_16003981_181010011426_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '229.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 229.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '139.0000001',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 139.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003937',
#    'name': 'Lise 4 Layers Slim Plastic Drawer Cabinet',
#    'averageRating': 4.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/f3eaf701ad4a65e1deca2e908ad3a8c66a1a43ff/h1888001_16003937_181006075801_01_300.jpg'}],
#    'brandName': 'JEJ',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '699.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 699.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '459.00002759999995',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 459.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005755',
#    'name': 'Plastic Stackable Kitchen Rack',
#    'averageRating': 5.0,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/267589/h1888001_16005755_210802045951_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '65.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 65.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '39.999999',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 40.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005842',
#    'name': 'froq Plastic Storage Box with Lid (M) - White',
#    'averageRating': 5.0,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/271154/h1888001_16005842_211102105646_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '289.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 289.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '179.00001079999998',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 179.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004713',
#    'name': '2 Tier Plastic Multi-purpose Extenable Kitchen Rack',
#    'averageRating': 4.3,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/d7e3738f464c408bba3c4e1ad197981ce0927b61/h1888001_16004713_190121102913_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '255.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 255.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '155',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 155.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003943',
#    'name': 'Lise 3 Layers Plastic Storage Rack with Wheels',
#    'averageRating': 4.5,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/50ce19bb5c3ba02186e958df3fef740261f115fb/h1888001_16003943_181006080942_01_300.jpg'}],
#    'brandName': 'JEJ',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '429.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 429.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '279.0000213',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 279.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005785',
#    'name': 'froq Plastic Storage Box with Lid - White (445W x 340D X 310Hmm)',
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/268937/h1888001_16005785_210812041910_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '249.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 249.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '159',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 159.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003975',
#    'name': 'Royal 4 Layers Wide Plastic Drawer Cabinet with Wooden (MDF) Board',
#    'averageRating': 4.5,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/65b5f87cc2baa901f029232b6c1241a7b80ee04e/h1888001_16003975_181006122253_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '2999.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 2,999.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '1899.0000889',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 1,899.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005823',
#    'name': 'Roll-up Silicone Dish Drying Rack (52x33cm)',
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/184179faf0254550779d8353276b310ee113500f/h1888001_16005823_211026094505_01_300.jpg'}],
#    'brandName': 'Kouwa',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '159.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 159.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '99.9000021',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 99.90'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003940',
#    'name': 'Lise 4 Layers Plastic Drawer Cabinet',
#    'averageRating': 4.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/df62f082e1492fd2349b9b9da052c3c62309e5b7/h1888001_16003940_180926071425_01_300.jpg'}],
#    'brandName': 'JEJ',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '899.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 899.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '599.0000141',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 599.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005228',
#    'name': "Lock'in Pod Plastic Storage Box with Lid (L)",
#    'averageRating': 4.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/1b47c2933e81512cd4564515f4939c802d25ec42/h1888001_16005228_200416025606_01_300.jpg'}],
#    'brandName': 'JEJ',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '529.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 529.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '319.0000134',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 319.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003978',
#    'name': 'Storanti4Layers SlimPlasticDrawerCabinet',
#    'averageRating': 4.0,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/c12e8223abe9ff3ad30d80fbddf51ec669520746/h1888001_16003978_201109103355_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '1099.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 1,099.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '548.999955',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 549.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004483',
#    'name': 'Plastic Adjustable Suction Hook',
#    'averageRating': 4.5,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/f4d05c25c80164fb72a52ef28d030ff3e9b250c2/h1888001_16004483_190110071649_01_300.jpg'}],
#    'brandName': 'AKEBONO',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '59.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 59.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '38.999997099999995',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 39.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004445',
#    'name': 'Plastic Tabletop Wire Collection Storage Box - S',
#    'averageRating': 4.5,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/1c8a8935a08d7d4cc6c502ecc0454f783d71efc4/h1888001_16004445_181226060900_01_300.jpg'}],
#    'brandName': 'INOMATA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '109.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 109.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '68.9999975',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 69.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16003860',
#    'name': '5 Layer Plastic Drawer Cabinet with MDF Wooden Cover (For Delivery Only)',
#    'averageRating': 3.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/50b2449b269ccb21472614f48641153bd034e790/h1888001_16003860_190110030815_01_300.jpg'}],
#    'brandName': 'Home Base',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '919.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 919.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '569.0000447',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 569.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16004715',
#    'name': '2 Tier Plastic Multi-purpose Extenable Kitchen Rack',
#    'averageRating': 4.4,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/bae7d1f87e6b87852b8de6ddb7dc5613106f2db5/h1888001_16004715_190121103255_01_300.jpg'}],
#    'brandName': 'Pearl',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '269.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 269.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '165.0000001',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 165.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []},
#   {'code': 'H1888001_S_16005837',
#    'name': 'froq Plastic Storage Box with Lid (S) - Dark  Brown',
#    'averageRating': 3.6,
#    'images': [{'imageType': 'PRIMARY',
#      'format': 'product',
#      'url': '//images.hktvmall.com/h1888001/9a246ad66b5895b0f38662228485cbb35a394418/h1888001_16005837_211102103935_01_300.jpg'}],
#    'brandName': 'SANKA',
#    'priceList': [{'currencyIso': 'HKD',
#      'priceType': 'BUY',
#      'value': '229.0',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 229.00'},
#     {'currencyIso': 'HKD',
#      'priceType': 'DISCOUNT',
#      'value': '139.0000001',
#      'membershipLevel': 'NORMAL',
#      'formattedValue': '$ 139.00'}],
#    'invisible': False,
#    'isFlashSale': False,
#    'isEcoupon': False,
#    'numberOfVariants': 0,
#    'isStockNotified': False,
#    'urgent': False,
#    'purchaseOption': 0,
#    'reservable': False,
#    'quantity': 0,
#    'userMax': 0,
#    'includeRemovalService': False,
#    'isInsurance': False,
#    'packingLength': 0.0,
#    'packingHeight': 0.0,
#    'packingDepth': 0.0,
#    'marketingLabelUids': []}],
#  'labels': [{'type': 'OFFER', 'name': 'Discount to $169.0'},
#   {'type': 'REBATE',
#    'name': '0% Mall Dollar Money Rebate',
#    'amount': 0.0,
#    'loyaltyPoint': '0'}],
#  'returnDays': 0,
#  'loyaltyPoint': '0.0',
#  'storeLogos': {'banner_url': '',
#   'logo_url': '//images.hktvmall.com/h1888001/h1888001_mobilelogo_171009090059.jpg'},
#  'priceList': [{'currencyIso': 'HKD',
#    'priceType': 'BUY',
#    'value': '299.0',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 299.00'},
#   {'currencyIso': 'HKD',
#    'priceType': 'DISCOUNT',
#    'value': '169.00000260000002',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 169.00'}],
#  'promotionStyle': 'GREY',
#  'productVideoUrls': {'playlist': []},
#  'thresholdPromotionList': [],
#  'bundlePromotionList': [],
#  'invisible': False,
#  'membershipLoyaltyPoint': [{'membershipLevel': 'NORMAL',
#    'loyaltyPoint': 0.0,
#    'priority': 0}],
#  'earliestDeliveryDateMsg': '* The product can be arranged to deliver within 24 hours the soonest when the order is placed',
#  'earliestDeliveryDetailMsg': 'This is only applicable for orders with all selected itemswith this label. The actual delivery date & time will dependon various factors such as delivery address, ordernumber & manpower allocation. Therefore, please refer tothe delivery date & time as displayed on “Confirm Payment”page.HKTVmall will make its best effort to provide the best & thesoonest delivery, and will reserve the final right of decision.',
#  'deliveryPeriodMode': 'standard-express',
#  'deliveryPeriodMsg': '24h Delivery/<br/>8h Self Pick Up',
#  'soldBy': 'The House',
#  'recommendedPrice': {'name': '',
#   'fontColor': '#000000',
#   'fontBgColor': '#FFFFFF',
#   'hasStrikeThrough': True},
#  'subCatRecommendation': [],
#  'skuLevelRecommendation': [],
#  'categoryLevelRecommendation': [],
#  'savedPrice': [{'currencyIso': 'HKD',
#    'priceType': 'DISCOUNT',
#    'value': '129.99999739999998',
#    'membershipLevel': 'NORMAL',
#    'formattedValue': '$ 130.00'}],
#  'productKeyword': 'F38289',
#  'subCatRecommendationName': '',
#  'skuLevelRecommendationName': '',
#  'categoryLevelRecommendationName': '',
#  'recommendationName': '',
#  'primaryCatCode': 'AA18050500001',
#  'isFlashSale': False,
#  'isEcoupon': False,
#  'summaryTitle': '',
#  'descriptionTitle': '',
#  'deliveryTitle': '',
#  'deliveryDetails': '',
#  'promotionBanners': [],
#  'numberOfVariants': 1,
#  'isStockNotified': False,
#  'urgent': False,
#  'purchaseOption': 0,
#  'reserveTC': '',
#  'reservable': False,
#  'createdTime': '2018-07-03 15:07:12',
#  'quantity': 0,
#  'perfectPartnerPromotion': {'code': 'Redemption_H1888001_Freshdisc1',
#   'name': 'The House redemption!',
#   'label': 'Redeem ToiletDuck Refill',
#   'description': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45) <br>The promotion is valid till 22-MAY-2022<br>Only available while stock lasts.',
#   'shortDescription': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45)',
#   'colorCode': '#CC0000',
#   'discountType': 'QUANTITY',
#   'startTime': 1651852800000,
#   'endTime': 1653235200000},
#  'perfectPartnerPromotionList': [{'code': 'Redemption_H1888001_Freshdisc1',
#    'name': 'The House redemption!',
#    'label': 'Redeem ToiletDuck Refill',
#    'description': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45) <br>The promotion is valid till 22-MAY-2022<br>Only available while stock lasts.',
#    'shortDescription': '【The House redemption!】Purchase The House Products to redeem ToiletDuck - Fresh Disc Refill at $37! (Orginal Price $45)',
#    'colorCode': '#CC0000',
#    'discountType': 'QUANTITY',
#    'startTime': 1651852800000,
#    'endTime': 1653235200000}],
#  'userMax': 0,
#  'userMaxMessage': '',
#  'zone': 'housewares',
#  'store': {'code': 'H1888001',
#   'name': 'The House',
#   'storeType': 'hktv_own_store',
#   'storeTypeDisplay': 'HKTV owned store',
#   'storeRating': 4.5,
#   'storeTags': [{'name': 'HKTV owned store',
#     'storeType': 'hktv_own_store',
#     'imageData': {'url': '/medias/sys_master/images/images/h4a/hf0/17011975061534.png',
#      'altText': 'HKTVStoreEN'}},
#    {'name': 'Fast Delivery Shop',
#     'storeType': 'frequent_delivery_store',
#     'imageData': {'url': '/medias/sys_master/images/images/hba/hd2/17011975454750.png',
#      'altText': 'fastDeliveryEN'}}]},
#  'deliveryLabel': {'deliveryMode': 'standard-express',
#   'name': 'Earliest 1 Day',
#   'bgColor': '#D8F7C5'},
#  'termsAndConditionsTitle': '',
#  'termsAndConditions': '',
#  'imageUrls': ['//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180730095716_01_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115533_02_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115536_03_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115539_04_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115542_05_1200.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_65.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_96.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_300.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_515.jpg',
#   '//images.hktvmall.com/h1888001/d39c59661c39bc6ebed610affae1233c00a6cda1/h1888001_16003423_180710115545_06_1200.jpg'],
#  'deliveryFeeLabel': {},
#  'deliveryFeeLabelVIP': {},
#  'includeRemovalService': False,
#  'isInsurance': False,
#  'warrantyText': '',
#  'primaryCatName': 'Plastic Storage Container',
#  'isLowStock': False,
#  'packingLength': 0.0,
#  'packingHeight': 0.0,
#  'packingDepth': 0.0,
#  'storeTags': [{'name': 'HKTV owned store',
#    'storeType': 'hktv_own_store',
#    'imageData': {'url': '/medias/sys_master/images/images/h4a/hf0/17011975061534.png',
#     'altText': 'HKTVStoreEN'}},
#   {'name': 'Fast Delivery Shop',
#    'storeType': 'frequent_delivery_store',
#    'imageData': {'url': '/medias/sys_master/images/images/hba/hd2/17011975454750.png',
#     'altText': 'fastDeliveryEN'}}],
#  'priceChartUrl': 'hktv/zh/priceChart?skuCode=H1888001_S_16003423',
#  'hasCnaForm': False,
#  'isSingleSkuCheckout': False,
#  'specialAddCartFlowLink': '',
#  'marketingLabels': [],
#  'marketingLabelUids': [],
#  'insuranceRemark': '',
#  'countRecommended': 0,
#  'totalRecommendation': 2,
#  'recommendPercent': 0,
#  'videos': {'galleryUrls': []},
#  'presellSku': False,
#  'inStorePickUpCheckoutLink': '',
#  'isLiteAppExcluded': False}

# %%
len(all_products_links)
# Out:
# 55226

# %% [markdown]
# # Master Loop

# %%
zones = ["thirteenlandmarks","supermarket","personalcarenhealth","beautynhealth","homenfamily","housewares","deals","sportsntravel"]
headers = {
    "accept-encoding":"gzip",
    "authorization":"Bearer 2de2ea56-4e3c-4401-9a76-c014c70bdc08",
    "connection":"Keep-Alive",
    "cookie":"LBI=-1941669348; inapp=true; fence=0; JSESSIONID=7666D5240B540824DE19EFA71540EF49",
    "device-type":"android",
    "host":"www.hktvmall.com",
    "ott-uuid":"97665ca7-880e-43ce-8a11-5429d7a8a934",
    "user-agent":"okhttp/2.2.0"
}

all_pages = []
all_pages_links = []
products_page_url_base = "https://www.hktvmall.com/hktvwebservices/v1/hktv/search_products_v2?query="

for zone in zones:
    categories = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_category_directory?lang=en&zone="+zone+"&maxLevel=3"
    cat = requests.get(categories,headers = headers).json()
     
    for category in cat['categories'] :

        if 'subcats' in category.keys():        
            for subcat1 in category['subcats']:

                if 'subcats' in subcat1.keys():
                    for subcat2 in subcat1['subcats']:

                        if 'subcats' in subcat2.keys():                     
                            for subcat3 in subcat2['subcats']:
                                all_pages.append(subcat3)

                        else:
                            all_pages.append(subcat2)                    
                else:
                    all_pages.append(subcat1)
        else :
            all_pages.append(category)
    

for pg in all_pages:
    all_pages_links.append(products_page_url_base+urllib.parse.quote(pg['query'])+"&lang=en&currentPage=0&pageSize=100000&user_id=anonymous")

all_products_links = []
lengthpg = len(all_pages_links)
for i,lnk in enumerate(all_pages_links) :
    multiple_prod_pg = requests.get(lnk,headers=headers).json()
    
    for prd in multiple_prod_pg['products']:
        all_products_links.append(prd)
        sys.stdout.write(f"\rGenerating Product links %i /{lengthpg}" % i)
        sys.stdout.flush() 

        
product_codes = []
for cde in all_products_links:
    product_codes.append(cde['code'])

product_codes = list(set(product_codes))    

product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
lengthp = len(product_codes)
for i,pr_lnk in enumerate(product_codes):
    url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = head).json())
    sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
    sys.stdout.flush() 
    
with open('hktvdata.json', 'w') as outfile:
        json.dump(products, outfile)
        outfile.close()
# Out:
# Scraping product 466 /7485259 /2170
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13900/789568712.py in <module>
#      57 for i,pr_lnk in enumerate(all_products_links):
#      58     url = product_base_link+pr_lnk['code']+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ---> 59     products.append(requests.get(url,headers = head).json())
#      60     sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
#      61     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# c:\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# c:\python\python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# c:\python\python39\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# c:\python\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# c:\python\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# c:\python\python39\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
len(all_products_links)
# Out:
# 748525

# %%
product_codes[0]
# Out:
# 'H8450001_S_545_00002'

# %%
product_codes = []
for cde in all_products_links:
    product_codes.append(cde['code'])

product_codes = list(set(product_codes))

# %%
len(product_codes)
# Out:
# 466532

# %%
product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
products = []
lengthp = len(product_codes)
for i,pr_lnk in enumerate(product_codes):
    url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
    products.append(requests.get(url,headers = head).json())
    sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
    sys.stdout.flush() 
    
with open('hktvdata.json', 'w') as outfile:
        json.dump(products, outfile)
        outfile.close()
# Out:
# Scraping product 30 /466532
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21084/2551414564.py in <module>
#       4 for i,pr_lnk in enumerate(product_codes):
#       5     url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
# ----> 6     products.append(requests.get(url,headers = head).json())
#       7     sys.stdout.write(f"\rScraping product %i /{lengthp}" % i)
#       8     sys.stdout.flush()
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# c:\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# c:\python\python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# c:\python\python39\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# c:\python\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# c:\python\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# c:\python\python39\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
with open('codes.json', 'w') as outfile:
        json.dump(product_codes, outfile)
        outfile.close()

# %%
with open('codes.json') as json_file:
    product_codes = json.load(json_file)
    json_file.close()

# %%
products[0]['countryOfOrigin']
# Out:
# 'China'

# %%
final_product = {
    'timestamp':'',
    'source':'',
    'country_code':'',
    'restaurant_id':'',
    'category':'',
    'items':'',
    'unmapped':'',
    'description':'',
    'sort_order':'',
    'items':'',
    'item_name':'',
    'item_id':'',
    'description':'',
    'available':'',
    'alcohol':'',
    'popular':'',
    'price':'',
    'price_unit':'',
    'discounted_price':'',
    'takeaway_price':'',
    'discounted_takeaway_price':'',
    'image_url':'',
    'labels':'',
    'promotion':'',
    'sort_order':'',
    'modifier_groups':{
        'modifier_groups_id':'',
        'name':'',
    },
    
    
}

# %%
import threading

# %%
def scrape(lock,urls):
    product_base_link = "https://www.hktvmall.com/hktvwebservices/v1/hktv/get_product?product_id="
    products = []
    lengthp = len(urls)
    for i,pr_lnk in enumerate(urls):
        lock.acquire()
        global globb
        globb += 1
        lock.release()
        url = product_base_link+pr_lnk+"&lang=en&no_stock_redirect=true&user_id=anonymous"
        products.append(requests.get(url,headers = head).json())
        sys.stdout.write(f"\rScraping product %i /{lengthp}" % globb)
        sys.stdout.flush() 
    lock.acquire()
    with open('hktvdata.json', 'a') as outfile:
            json.dump(products, outfile)
            outfile.close()
    lock.release()

# %%
lock = threading.Lock()
global globb 
globb = 0
# creating threads
threads = []
for i in range(100):
    if i == 99:
        t = threading.Thread(target=scrape, args=(lock,product_codes[i*4665:-1]))
    else:
        t = threading.Thread(target=scrape, args=(lock,product_codes[i*4665:(i+1)*4665]))
    threads.append(t)
#t1 = threading.Thread(target=scrape, args=(lock,product_codes[:100]))
#t2 = threading.Thread(target=scrape, args=(lock,product_codes[100:200]))

        # start threads
#t1.start()
#t2.start()

        # wait until threads finish their job
#t1.join()
#t2.join()
[ t.start() for t in threads ]
    # wait for the threads to finish
[ t.join() for t in threads ]
# Out:
# Scraping product 1177 /4665
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "c:\python\python39\lib\site-packages\urllib3\connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "c:\python\python39\lib\ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "c:\python\python39\lib\ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "c:\python\python39\lib\ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python\python39\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "c:\python\python39\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "c:\python\python39\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "c:\python\python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "c:\python\python39\lib\site-packages\urllib3\connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "c:\python\python39\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "c:\python\python39\lib\ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "c:\python\python39\lib\ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "c:\python\python39\lib\ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python\python39\lib\threading.py", line 954, in _bootstrap_inner
#     self.run()
#   File "c:\python\python39\lib\threading.py", line 892, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\abhin\AppData\Local\Temp/ipykernel_19768/1372681307.py", line 11, in scrape
#   File "c:\python\python39\lib\site-packages\requests\api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "c:\python\python39\lib\site-packages\requests\api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "c:\python\python39\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "c:\python\python39\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "c:\python\python39\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Scraping product 1638 /4665

# %%
with open('codes1.json') as json_file:
    product_codes = json.load(json_file)
    json_file.close()
    
product_codes = list(set(product_codes))
len(product_codes)
# Out:
# 14011
