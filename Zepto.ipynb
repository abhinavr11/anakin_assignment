# %%
import requests

# %%
cate = "https://api.zepto.co.in/api/v1/inventory/catalogue/categories/?store_id=d6855f04-c753-4e3a-b7f6-864d6b64c450"

header = {
    "accept":"application/json",
"accept-encoding":"gzip",
"access-control-allow-credentials":"true",
"appversion":"5.20.4",
"authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2ODMzNjI1MTMsInN1YiI6IjhiMGU2MjY0LTVlOGYtNDE5Ni1hZmUxLTY2OWJiY2EzMTE5NyJ9.VWPVKQ9bGfm9WnFDl43eNlTGL37lfbZqa2xONRkI0yQ",
"bundleversion":"",
"compatible_components":"CONVENIENCE_FEE",
"connection":"Keep-Alive",
"device_brand":"Android",
"device_model":"Samsung Galaxy S8",
"deviceuid":"506e35ebdd37ffaf",
"host":"api.zepto.co.in",
"if-modified-since":"Fri, 06 May 2022 08:56:31 GMT",
"platform":"android",
"requestid":"b7270447-ec04-492d-b769-4a3c6473db2f",
"sessionid":"undefined",
"source":"PLAY_STORE",
"systemversion":"8.0.0",
"user-agent":"okhttp/3.12.12",
"x-requested-with":"XMLHttpRequest"
}

# %%
cat = requests.get(cate,headers = header).json()

# %%
cat['categories'][0]['availableSubcategories'][0]
# Out:
# {'id': 'e78a8422-5f20-4e4b-9a9f-22a0e53962e3',
#  'name': 'All',
#  'image': {'name': 'Fruit & Vegetables.png',
#   'path': 'inventory/category/b5fa10b2-023b-4a88-9fbf-5b00a989663e-Fruit_&_Vegetables.png',
#   'mediaType': 'IMAGE',
#   'width': 281,
#   'height': 245,
#   'id': '21e493e9-646b-4109-ae0f-08e3470dbd18'},
#  'secondaryImage': None,
#  'priority': 10,
#  'unlisted': False,
#  'isActive': None,
#  'category': {'name': 'Fruits & Vegetables',
#   'id': '64374cfe-d06f-4a01-898e-c07c46462c36',
#   'image': {'name': 'Fruit & Vegetables.png',
#    'path': 'inventory/category/b5fa10b2-023b-4a88-9fbf-5b00a989663e-Fruit_&_Vegetables.png',
#    'mediaType': 'IMAGE',
#    'width': 281,
#    'height': 245,
#    'id': '21e493e9-646b-4109-ae0f-08e3470dbd18'},
#   'priority': 10,
#   'unlisted': False},
#  'displaySecondaryImage': True,
#  'facebookSubcategory': None,
#  'googleSubcategory': None,
#  'priceGuardrailThreshold': None,
#  'itemPreperationBuffer': None}

# %%
prod_u = "https://api.zepto.co.in/api/v2/inventory/catalogue/store-products/?store_id=d6855f04-c753-4e3a-b7f6-864d6b64c450&subcategory_id=e78a8422-5f20-4e4b-9a9f-22a0e53962e3&page_number=2"

prods_p = requests.get(prod_u,headers=header).json()

# %%
prods_p
# Out:
# {'storeProducts': [{'recommendationId': None,
#    'objectId': 'f258ad15-9ab5-40fe-a5ce-51015671c189',
#    'id': 'f258ad15-9ab5-40fe-a5ce-51015671c189',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'c7c6fae7-2102-4203-b43d-55c902e76299',
#     'name': 'Carrot',
#     'brand': '',
#     'imported': True,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Cabbage', 'Shreds']},
#    'productVariant': {'id': '54447996-7ace-4af2-8cfc-a5d1dfc28838',
#     'quantity': 500,
#     'mrp': 10000,
#     'packsize': 500.0,
#     'weightInGms': 500.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'c7c6fae7-2102-4203-b43d-55c902e76299.jpeg',
#       'path': 'inventory/product/963724eb-2471-41fa-be98-f5cbf1d5d7ab-c7c6fae7-2102-4203-b43d-55c902e76299.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 684,
#       'height': 513,
#       'id': 'e1a12fae-3fdf-4fdb-9887-72117acbd575'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2800,
#    'discountPercent': 15.0,
#    'discountAmount': 500,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3300,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2800},
#   {'recommendationId': None,
#    'objectId': '8d550878-0c25-45f4-bc58-b649f1d60c7f',
#    'id': '8d550878-0c25-45f4-bc58-b649f1d60c7f',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'cfedb00b-492c-4021-9879-1edb34b96bf0',
#     'name': 'Papaya',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['papaya', 'papita', 'fruit', 'papya', 'fresh fruits']},
#    'productVariant': {'id': '105c48cc-d5cb-4279-ac58-fe36cc92d51d',
#     'quantity': 1,
#     'mrp': 6300,
#     'packsize': 1.0,
#     'weightInGms': 58.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': '12344427.jpeg',
#       'path': 'inventory/product/a217005d-8945-4a74-b194-ae03b0fd0ace-12344427.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 1000,
#       'height': 799,
#       'id': '0de8def2-0847-4e3b-9384-4bbf40531611'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 4200,
#    'discountPercent': 16.0,
#    'discountAmount': 800,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 5000,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 4200},
#   {'recommendationId': None,
#    'objectId': 'a7e3b6cc-dba4-4738-9277-1ec5c2a9bfe3',
#    'id': 'a7e3b6cc-dba4-4738-9277-1ec5c2a9bfe3',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '9bc563ec-5aa4-4049-a664-a228095fd039',
#     'name': 'Capsicum',
#     'brand': '',
#     'imported': True,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': None},
#    'productVariant': {'id': '366e4979-209d-484e-880e-1363c3fa6b1a',
#     'quantity': 500,
#     'mrp': 10000,
#     'packsize': 500.0,
#     'weightInGms': 500.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '9bc563ec-5aa4-4049-a664-a228095fd039.jpeg',
#       'path': 'inventory/product/1316e5b5-1879-4014-9fdf-773197d0ad0f-9bc563ec-5aa4-4049-a664-a228095fd039.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': '475df30c-b623-477b-8781-5f193d0e8be7'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 3000,
#    'discountPercent': 16.0,
#    'discountAmount': 600,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3600,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 3000},
#   {'recommendationId': None,
#    'objectId': '2742372d-3fe5-4962-8c8b-c25cf88c302c',
#    'id': '2742372d-3fe5-4962-8c8b-c25cf88c302c',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '097197fc-a34d-4f4a-9dbb-9e3891e15031',
#     'name': 'Bitter Gourd',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Bitter', 'Gourd', 'Karela']},
#    'productVariant': {'id': '8fe14d1e-a38b-4c8e-bc9e-fa29f57bf7b0',
#     'quantity': 250,
#     'mrp': 1500,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'large_bittergourd.jpg',
#       'path': 'inventory/product/ada53b70-802c-4dae-8333-2ec4c66b5506-large_bittergourd.jpg',
#       'mediaType': 'IMAGE',
#       'width': 356,
#       'height': 235,
#       'id': '938505cd-8668-4eb8-9983-9d32ef416c82'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1300,
#    'discountPercent': 13.0,
#    'discountAmount': 200,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 1500,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1300},
#   {'recommendationId': None,
#    'objectId': '1cd13eba-599c-4029-9812-0ba1a13a438e',
#    'id': '1cd13eba-599c-4029-9812-0ba1a13a438e',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'a87d6c85-8184-428d-a877-070f4f55ffb5',
#     'name': 'Apple Shimla',
#     'brand': 'Malgudi',
#     'imported': True,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': None},
#    'productVariant': {'id': '3641997e-8417-4718-86a7-c6b557a04de9',
#     'quantity': 4,
#     'mrp': 13500,
#     'packsize': 4.0,
#     'weightInGms': 232.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': 'a87d6c85-8184-428d-a877-070f4f55ffb5.jpeg',
#       'path': 'inventory/product/b27145e6-2738-4a32-9fe6-84546846d714-a87d6c85-8184-428d-a877-070f4f55ffb5.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 900,
#       'height': 900,
#       'id': '3a63198a-514a-46de-88ac-ca96df2f8f44'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 11700,
#    'discountPercent': 15.0,
#    'discountAmount': 2200,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 13900,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 11700},
#   {'recommendationId': None,
#    'objectId': 'f0804084-e234-4f20-b3e9-63a5f7b1eaba',
#    'id': 'f0804084-e234-4f20-b3e9-63a5f7b1eaba',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '438bc8cc-ce53-4e1e-8276-597dbaed220a',
#     'name': 'Sweet Corn',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Sweet Corn', 'Corn', 'Makka', 'Kanis', 'Bhutta']},
#    'productVariant': {'id': '1593900c-9204-4f68-982e-b16ab6010e08',
#     'quantity': 2,
#     'mrp': 3600,
#     'packsize': 2.0,
#     'weightInGms': 116.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': '95296862.jpeg',
#       'path': 'inventory/product/4f02cf02-b68d-4883-8fd0-793744784893-95296862.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 450,
#       'height': 450,
#       'id': '93b29ab1-96ac-4fd5-83f8-6bf7b3d2b696'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 3100,
#    'discountPercent': 16.0,
#    'discountAmount': 600,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3700,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 3100},
#   {'recommendationId': None,
#    'objectId': 'e4ddc77a-84d5-4f1a-9d80-2121483ea51b',
#    'id': 'e4ddc77a-84d5-4f1a-9d80-2121483ea51b',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'eab1996d-b1e4-40f9-b465-f1688da99ba4',
#     'name': 'Garlic',
#     'brand': '',
#     'imported': True,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': None},
#    'productVariant': {'id': '5916b525-34af-4914-9019-233a5c3d8f5e',
#     'quantity': 200,
#     'mrp': 10000,
#     'packsize': 200.0,
#     'weightInGms': 200.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'eab1996d-b1e4-40f9-b465-f1688da99ba4.jpeg',
#       'path': 'inventory/product/ef3f4ec3-bee8-48bf-b829-e1d04a8401f0-eab1996d-b1e4-40f9-b465-f1688da99ba4.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': '29b7dd49-e957-4f12-9dc5-d5855ff18755'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1600,
#    'discountPercent': 15.0,
#    'discountAmount': 300,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 1900,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1600},
#   {'recommendationId': None,
#    'objectId': '56d9efeb-7a39-43d8-b6e7-f0201df8aaef',
#    'id': '56d9efeb-7a39-43d8-b6e7-f0201df8aaef',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '8b0dc295-f340-4895-98eb-15aee4f56a8a',
#     'name': 'Brinjal Small',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Small Brinjal',
#      'Baingan',
#      'Brinjal',
#      'Vegetable',
#      'bengan']},
#    'productVariant': {'id': 'a72d4112-a6d1-46f2-b41c-df96d2c7bd79',
#     'quantity': 250,
#     'mrp': 1900,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'brinjal small.jpg',
#       'path': 'inventory/product/48a9a0f5-f26c-4913-82ad-ea08f290a31e-brinjal_small.jpg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': '5053f12f-5ffc-4900-bc0e-7ed8295a6613'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1800,
#    'discountPercent': 14.0,
#    'discountAmount': 300,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 2100,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1800},
#   {'recommendationId': None,
#    'objectId': '129b9da2-be6e-44c1-a94d-f3379ba07482',
#    'id': '129b9da2-be6e-44c1-a94d-f3379ba07482',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '4a6618b3-069d-4941-a025-7ac0c11cf334',
#     'name': 'Spring Onion ',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Spring Onion',
#      'Hara Pyaaz',
#      'Onion',
#      'Pyaaz',
#      'Vegetable']},
#    'productVariant': {'id': '41e44169-b614-4646-8f0a-4622785b28a0',
#     'quantity': 250,
#     'mrp': 3100,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '10290886.jpeg',
#       'path': 'inventory/product/e0063383-5b78-42b4-9a57-28167c387461-10290886.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 750,
#       'height': 750,
#       'id': 'b99dd4bb-de90-4ee3-a86f-8b786ad49bbd'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2800,
#    'discountPercent': 15.0,
#    'discountAmount': 500,
#    'storeProductDiscountId': None,
#    'availableQuantity': 1,
#    'outOfStock': False,
#    'mrp': 3300,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2800},
#   {'recommendationId': None,
#    'objectId': 'a52386f2-16a7-4b14-8441-74a48258ee3c',
#    'id': 'a52386f2-16a7-4b14-8441-74a48258ee3c',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '2624a3d5-a323-4040-b788-15a6b5c1922c',
#     'name': 'Lettuce Iceberg',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Lettuce Iceberg',
#      'Moola',
#      'Cabbage',
#      'Green Vegetable',
#      'letuce',
#      'salad']},
#    'productVariant': {'id': 'd88c98a2-1aa0-4be0-881e-b44d1386ef4f',
#     'quantity': 250,
#     'mrp': 5000,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'image_file.png',
#       'path': 'inventory/product/af6abaf0-9a3f-4558-ac19-8cc9f6cf9f59-image_file.png',
#       'mediaType': 'IMAGE',
#       'width': 589,
#       'height': 424,
#       'id': 'db28a321-98c9-42b5-bbf9-27cb89b12a70'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 6500,
#    'discountPercent': 17.0,
#    'discountAmount': 1400,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 7900,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 6500},
#   {'recommendationId': None,
#    'objectId': 'b66efe8b-fd0c-49fd-9559-4b39437ccbf4',
#    'id': 'b66efe8b-fd0c-49fd-9559-4b39437ccbf4',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'ecbec63e-e760-4f23-9f9e-0ec6aeb22cbe',
#     'name': 'Bell Peppers Red & Yellow ',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Red Bell Peppers',
#      'Yellow Bell Peppers',
#      'Shimla Mirch',
#      'Laal Shimla Mirch',
#      'Peeli Shimla Mirch',
#      'fresh vegetables']},
#    'productVariant': {'id': '791b4663-4ce2-4de1-863c-668c5431c797',
#     'quantity': 2,
#     'mrp': 9400,
#     'packsize': 2.0,
#     'weightInGms': 116.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': '75669751.jpeg',
#       'path': 'inventory/product/c5c488b4-88fc-4d9f-9df3-8511970f2f20-75669751.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 855,
#       'height': 678,
#       'id': 'd8eaf042-4b55-4790-968f-20a6c820625b'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 7500,
#    'discountPercent': 18.0,
#    'discountAmount': 1700,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 9200,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 7500},
#   {'recommendationId': None,
#    'objectId': 'c1278b8f-3248-441a-ba3b-2e8ffaca1e48',
#    'id': 'c1278b8f-3248-441a-ba3b-2e8ffaca1e48',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '72fd8526-90f1-41e5-a17b-93c36141fdba',
#     'name': 'Baby Potato',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Baby', 'Corn', 'Peeled', 'Corn Peeled']},
#    'productVariant': {'id': '46f30803-91f9-4798-a084-654fc50da311',
#     'quantity': 500,
#     'mrp': 2500,
#     'packsize': 500.0,
#     'weightInGms': 500.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'baby_potatoes-removebg-preview.png',
#       'path': 'inventory/product/80f5b86e-5b9f-4918-98d4-11ce43b41472-baby_potatoes-removebg-preview.png',
#       'mediaType': 'IMAGE',
#       'width': 450,
#       'height': 450,
#       'id': '11bc1537-b00a-4481-b206-4e3416894f97'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2000,
#    'discountPercent': 16.0,
#    'discountAmount': 400,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 2400,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2000},
#   {'recommendationId': None,
#    'objectId': '4a432bb5-e3df-436f-ab3d-851e19268334',
#    'id': '4a432bb5-e3df-436f-ab3d-851e19268334',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '9e7d2a7b-1bc0-4502-b399-64d8feb74620',
#     'name': 'Beans Cluster',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Cluster Beans',
#      'ganvaar phalee',
#      'beans',
#      'gwarfali',
#      'gwar fale',
#      'gvar fali',
#      'gvarphalee',
#      'beans',
#      'veggies',
#      'fresh vegetables',
#      'vegetables']},
#    'productVariant': {'id': '5c680ada-0828-4561-9990-721588ea9bb8',
#     'quantity': 250,
#     'mrp': 3800,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '27357233.jpeg',
#       'path': 'inventory/product/7c60bc13-d446-4bd8-ae74-d91a697fbea5-27357233.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 720,
#       'height': 630,
#       'id': '28718b36-b24b-42e3-a6a5-5708150d8d43'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1300,
#    'discountPercent': 13.0,
#    'discountAmount': 200,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 1500,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1300},
#   {'recommendationId': None,
#    'objectId': '8a50e90c-6ce1-49ee-ab55-a40b99a1fc4f',
#    'id': '8a50e90c-6ce1-49ee-ab55-a40b99a1fc4f',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '3f596128-aeba-4cc7-8106-1f248c8da3da',
#     'name': 'Beetroot',
#     'brand': '',
#     'imported': True,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': None},
#    'productVariant': {'id': '7dcf52c3-3901-4a58-a1bc-151fddfe3548',
#     'quantity': 500,
#     'mrp': 10000,
#     'packsize': 500.0,
#     'weightInGms': 500.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '3f596128-aeba-4cc7-8106-1f248c8da3da.jpeg',
#       'path': 'inventory/product/00b62932-fa7e-409e-97b0-975a641ac8dc-3f596128-aeba-4cc7-8106-1f248c8da3da.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 696,
#       'height': 503,
#       'id': '6ea1e122-e006-45e5-9efe-3602ea40d12f'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1500,
#    'discountPercent': 16.0,
#    'discountAmount': 300,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 1800,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1500},
#   {'recommendationId': None,
#    'objectId': 'e8f79d46-2f2a-4367-b323-e38439ae2136',
#    'id': 'e8f79d46-2f2a-4367-b323-e38439ae2136',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '47f08209-69ca-4cac-899b-009e77369a33',
#     'name': 'Coccinia',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Ivy Gourd',
#      'Tindli',
#      'vegetables',
#      'veg',
#      'tondli',
#      'tinli',
#      'tindali',
#      'ivy']},
#    'productVariant': {'id': '418a01f2-9464-47ff-bd5b-5645c6df28ff',
#     'quantity': 250,
#     'mrp': 3000,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '89053304.jpeg',
#       'path': 'inventory/product/b4e907c8-1eb8-45d0-a3a1-024761a961b1-89053304.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 679,
#       'height': 390,
#       'id': '084a3821-16e0-487c-80a8-b06b15668e47'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 1500,
#    'discountPercent': 16.0,
#    'discountAmount': 300,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 1800,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 1500},
#   {'recommendationId': None,
#    'objectId': '0d66ca8e-e1e2-4e9b-8e25-39ac925faad7',
#    'id': '0d66ca8e-e1e2-4e9b-8e25-39ac925faad7',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '27ba1e7f-4166-4362-aee2-6fda4bd3a74d',
#     'name': 'Pomegranate ',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['pomegranate',
#      'anaar',
#      'fruit',
#      'dalim',
#      'fresh fruits',
#      'pomogranet',
#      'pomgrant',
#      'anar',
#      'dadam']},
#    'productVariant': {'id': '84f0a260-3bf2-4ab0-a242-a1cd2c0e4a8f',
#     'quantity': 2,
#     'mrp': 10900,
#     'packsize': 2.0,
#     'weightInGms': 116.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': '2 pcs',
#     'images': [{'name': '87263467.jpeg',
#       'path': 'inventory/product/667f481a-0434-474e-bd9e-68967d1d1cb9-87263467.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 393,
#       'id': '99765557-fd98-4144-ab5a-2295a66ada04'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 11400,
#    'discountPercent': 16.0,
#    'discountAmount': 2200,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 13600,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 11400},
#   {'recommendationId': None,
#    'objectId': 'e7f008ef-dd48-4fd0-983f-7d7a721c1cf7',
#    'id': 'e7f008ef-dd48-4fd0-983f-7d7a721c1cf7',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '175f3952-f710-453c-9ace-c0626dbf677b',
#     'name': 'Mixed Sprouts',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Mixed Sprouts', 'Healthy Sprouts', 'Ankurit Salad']},
#    'productVariant': {'id': 'cef82c0e-a3cd-4906-81c9-08928700e16f',
#     'quantity': 200,
#     'mrp': 4600,
#     'packsize': 200.0,
#     'weightInGms': 200.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'mixed sprouts.PNG',
#       'path': 'inventory/product/f7c1a962-c1d2-4970-a259-9ae7b2d1072d-mixed_sprouts.PNG',
#       'mediaType': 'IMAGE',
#       'width': 468,
#       'height': 426,
#       'id': '5d6f9cab-d10b-4014-bb93-6b98203756ca'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2800,
#    'discountPercent': 17.0,
#    'discountAmount': 600,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3400,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2800},
#   {'recommendationId': None,
#    'objectId': 'bc5d7b1e-3796-4847-a732-97a7efe123f6',
#    'id': 'bc5d7b1e-3796-4847-a732-97a7efe123f6',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '607e3208-21d3-4914-b1ae-dc2d3d1d4f41',
#     'name': 'Sweet Lime',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Sweet Lime',
#      'Mosambi',
#      'Fruit',
#      'fresh fruit',
#      'citric fruit']},
#    'productVariant': {'id': 'aadd01af-1df0-4843-ae4e-aac9297804de',
#     'quantity': 2,
#     'mrp': 2900,
#     'packsize': 2.0,
#     'weightInGms': 116.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': 'image_file.jpeg',
#       'path': 'inventory/product/0fe16c4d-57af-460a-b8b1-ad90ee3511c0-image_file.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 450,
#       'height': 254,
#       'id': '7cafea6f-28c6-4793-ae26-acff98d0ec90'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2500,
#    'discountPercent': 16.0,
#    'discountAmount': 500,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3000,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2500},
#   {'recommendationId': None,
#    'objectId': '1df7a462-61ce-461a-b978-1676e7696512',
#    'id': '1df7a462-61ce-461a-b978-1676e7696512',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '01d989df-d37f-496c-a633-379867cf63d2',
#     'name': 'Guava',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': None},
#    'productVariant': {'id': '991a55a4-f0b9-42d3-a90d-f657923fe575',
#     'quantity': 4,
#     'mrp': 6300,
#     'packsize': 4.0,
#     'weightInGms': 232.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': 'image_file.png',
#       'path': 'inventory/product/9305a409-0583-413c-bcaa-8b21e0c3b48d-image_file.png',
#       'mediaType': 'IMAGE',
#       'width': 1080,
#       'height': 1080,
#       'id': '849c8221-648f-4e45-a2f4-d2fa9442773a'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 4000,
#    'discountPercent': 16.0,
#    'discountAmount': 800,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 4800,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 4000},
#   {'recommendationId': None,
#    'objectId': 'da8e584f-3cef-41ca-9d86-419f725848fc',
#    'id': 'da8e584f-3cef-41ca-9d86-419f725848fc',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '1de7ae48-2f76-495d-99f0-a98510b22295',
#     'name': 'Mango Raw',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['raw mango',
#      'kachha mango',
#      'kachha aam',
#      'aam',
#      'kacha aam',
#      'kacha mango']},
#    'productVariant': {'id': '084c1ec1-4447-40c6-90ed-4c1b56d2a72d',
#     'quantity': 500,
#     'mrp': 7800,
#     'packsize': 500.0,
#     'weightInGms': 500.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '77303062.jpeg',
#       'path': 'inventory/product/bbf2e07c-d6e0-4437-b192-f0ef39e82d72-77303062.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 1000,
#       'height': 1000,
#       'id': '438a942e-4e2f-4cbb-a165-2c0bf122af36'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2700,
#    'discountPercent': 15.0,
#    'discountAmount': 500,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3200,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2700},
#   {'recommendationId': None,
#    'objectId': 'e14c1931-5573-4fc3-b50e-9b8f35f4b7b8',
#    'id': 'e14c1931-5573-4fc3-b50e-9b8f35f4b7b8',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'cb642d57-3a5a-471c-9366-899cf0046252',
#     'name': 'Apple Washington',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['apple',
#      'seb',
#      'aple',
#      'fruits',
#      'fruit',
#      'fresh fruits']},
#    'productVariant': {'id': '2fbfb427-0aa2-48cd-bc90-b40fd22c4867',
#     'quantity': 4,
#     'mrp': 23600,
#     'packsize': 4.0,
#     'weightInGms': 232.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': '59347896.jpeg',
#       'path': 'inventory/product/7a0ca3d7-28f4-48a8-b1a6-729035367012-59347896.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': '55a6e26b-a936-42f1-8a16-15406cf1a513'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 12400,
#    'discountPercent': 16.0,
#    'discountAmount': 2400,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 14800,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 12400},
#   {'recommendationId': None,
#    'objectId': 'cef40193-a99e-435b-8a03-20427b3e7755',
#    'id': 'cef40193-a99e-435b-8a03-20427b3e7755',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'c3fec98f-a299-4ee6-910a-9347790bc41c',
#     'name': 'Orange',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Onion.Pyaaz', 'Onion Pyaaz']},
#    'productVariant': {'id': 'a28bf483-5b50-4469-a052-0fcebad0676b',
#     'quantity': 2,
#     'mrp': 8300,
#     'packsize': 2.0,
#     'weightInGms': 116.0,
#     'unitOfMeasure': 'PIECE',
#     'formattedPacksize': None,
#     'images': [{'name': 'Orange.png',
#       'path': 'inventory/product/25a5471a-01d2-4b2c-9afc-fccfaa4dba7b-Orange.png',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': 'add41d10-83f9-4e43-b0c8-ca2fb1504792'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 3300,
#    'discountPercent': 15.0,
#    'discountAmount': 600,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 3900,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 3300},
#   {'recommendationId': None,
#    'objectId': '42680fc5-d24d-4dfc-b685-3482dbcf9388',
#    'id': '42680fc5-d24d-4dfc-b685-3482dbcf9388',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': '1f8dd928-5707-4a83-871f-27c0f0d85d23',
#     'name': 'Lettuce Green',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Lettuce Green',
#      'Green Salad',
#      'Hara Salad',
#      'salad',
#      'veggies',
#      'letuce']},
#    'productVariant': {'id': 'dc6983dc-ba87-4931-ae79-451d7b4b97b4',
#     'quantity': 100,
#     'mrp': 3100,
#     'packsize': 100.0,
#     'weightInGms': 100.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': '1f8dd928-5707-4a83-871f-27c0f0d85d23.jpeg',
#       'path': 'inventory/product/4ca05bd5-bdfe-4ce5-822e-654cd4ac5880-1f8dd928-5707-4a83-871f-27c0f0d85d23.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 500,
#       'height': 500,
#       'id': '01787ac5-2a8a-415a-8a81-37918f97ccbb'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 3300,
#    'discountPercent': 17.0,
#    'discountAmount': 700,
#    'storeProductDiscountId': None,
#    'availableQuantity': 3,
#    'outOfStock': False,
#    'mrp': 4000,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 3300},
#   {'recommendationId': None,
#    'objectId': '8a2ff31b-3143-4873-9b06-c4090bbcd681',
#    'id': '8a2ff31b-3143-4873-9b06-c4090bbcd681',
#    'storeId': 'd6855f04-c753-4e3a-b7f6-864d6b64c450',
#    'product': {'id': 'db470c2e-c052-42ad-9430-c2fc8b4593dd',
#     'name': 'Amla',
#     'brand': '',
#     'imported': False,
#     'countryOfOrigin': None,
#     'minimumRequiredAge': 0,
#     'discountApplicable': True,
#     'searchKeywords': ['Gooseberry', 'Amla', 'Awlla', 'awla', 'avla']},
#    'productVariant': {'id': 'c0f58181-a3db-4f8e-93ee-e8d51ba3251e',
#     'quantity': 250,
#     'mrp': 3800,
#     'packsize': 250.0,
#     'weightInGms': 250.0,
#     'unitOfMeasure': 'GRAM',
#     'formattedPacksize': None,
#     'images': [{'name': 'db470c2e-c052-42ad-9430-c2fc8b4593dd.jpeg',
#       'path': 'inventory/product/b10309e1-a3b9-4ad1-8ed0-d6f5b1483f37-db470c2e-c052-42ad-9430-c2fc8b4593dd.jpeg',
#       'mediaType': 'IMAGE',
#       'width': 800,
#       'height': 600,
#       'id': '15a48837-255c-4565-9806-0a86e270ba53'}],
#     'maxAllowedQuantity': 3},
#    'discountedSellingPrice': 2400,
#    'discountPercent': 17.0,
#    'discountAmount': 500,
#    'storeProductDiscountId': None,
#    'availableQuantity': 1,
#    'outOfStock': False,
#    'mrp': 2900,
#    'productType': 'SELLABLESKU',
#    'priority': None,
#    'cached': True,
#    'sellingPrice': 2400}],
#  'endOfList': False}
